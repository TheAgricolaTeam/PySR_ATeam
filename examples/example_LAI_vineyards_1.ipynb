# %% [markdown]
# ### Example of Symbolic Regression to estimate LAI from spectral and structural data in vineyards
#
# Data generated by Sergio Alvarez, GRAPEX project.
#
# Utah State University, 2025.
#
# File '03_df_bands_structure_VI_LAI_NDVIc.csv' contains as potential predictors
# - Reflectance values from canopy
# - Vegetation indices for canopy
# - Geometric information (H, widht, etc) per vine
# - two predictants (afc, LAI) in the last colunms.
#
# In this example, we look to model LAI using reflectance and VIs generated by Symbolic Regression. So, we just give the form the the ND form = ((A-B)/(A+B)) and SR = A/B.

# %% [markdown]
# ### Instructions
# - if not, create a anaconda environment, e.g.
# ```bash
# conda create -n pysr
# ```
# - once completed the step above in the pysr environment install these modules:
# ```bash
# conda install pysr
# conda install matplotlib
# pip install skillmetrics
# ```
# - final step, in the activated environment and pass this command:
# ```bash
# - python -c "import pysr"
# ```
# - last commands will install julia libraries, necessary to run the notebook.
#
# - To visualize the results install Jinja2
# ```bash
# conda install jinja2
# ```

# %% [markdown]
# ### Running PySR
#
# Julia and Julia dependencies are installed at first import:

# %%
import pysr

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import warnings
warnings.filterwarnings('ignore')

import sympy as sp
import numpy as np
import pandas as pd
import skill_metrics as sm
import mpl_scatter_density # adds projection='scatter_density'

from pysr import PySRRegressor
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ### Set up PySR run:

# %% [markdown]
# using Sergio's data

# %%
df = pd.read_csv('03_df_bands_structure_VI_LAI_NDVIc.csv')
# print(df.head())
X = df.iloc[:,1:5]
y = df.iloc[:,-2]
print(y.head())
# Out:
# 0    1.47
# 1    1.50
# 2    1.18
# 3    1.16
# 4    1.19
# Name: LAI, dtype: float64

# %% [markdown]
# key pySR parameters to be changed:

# %%
niterations = 1000  # for short runs, set this to a 100, for longer runs, set this to 10 million
timeout_in_seconds = 3600*1  # this line will make the code stop after 2 hours, change it as desired.
elementwise_loss = "L2DistLoss()"  #  ("L2DistLoss()" mean square) can be changed to "L1DistLoss()" for mean absolute error, see link at the end for more options
# https://juliaml.github.io/LossFunctions.jl/stable/losses/distance/
binary_operators=["+", "*","-","/"] # these are the default binary operators (use these for basic equations)
binary_operators.extend(["ND(x,y) = ((x-y)/(x+y))", # activate this line to use simple ratio and normalized diference functions (comment the repvious line)
                         "SR(x,y)=x/y", 
                         "CC(x,y)=x/(x+y)",
                         "ID(x,y)=(1/x)-(1/y)",
                         "NP(x,y)=x*y/(x+y)",
                        #  "MSR(x,y) = (y == 0 || !isfinite(x / y)) ? (zero(x) / zero(x)) : ((x / y) - one(x)) / sqrt(abs((x / y) + one(x)))"
                         ])  # activate this line to use simple ratio and normalized diference functions (comment the repvious line)
# unary_operators = ["sqrt", "inv(x)= 1/x"]  # other basic operators can be added here
extra_sympy_mappings = {"ND": lambda x, y: ((x- y)/(x+y)),
                        "SR": lambda x, y: x/y, 
                        "CC": lambda x, y: x/(x+y),
                        "ID": lambda x, y: (1/x)-(1/y),
                        "NP": lambda x, y: x*y/(x+y),
                        # "inv": lambda x: 1 / x,
                        # "MSR":lambda x, y:((x/y)-1)/(((x/y)+1)**0.5)
                        }  # here the format of the sought expressions are defined

# %% [markdown]
# The default parameters will help speed up code and ensure repeteability of run

# %%
default_pysr_params = dict(
    model_selection="best", #'accuracy', 'best', or 'score', see documentation for more options
    random_state=0, # seed number to ensure reproducible results across different runs
    deterministic=True, #   to ensure reproducible results across different runs
    parallelism="serial", # to ensure reproducible results across different runs
    maxsize=40, # maximum complexity of the equations, increase to 100 for more complex equations, reduce to 20 for less complex equations   
    maxdepth=25,
    # select_k_features=10, # to automatically select few predictors (using random forest) from set of predictors, activate/deactive as you wish
    # denoise=True, # to remove scattering on y, activate/deactivate as you wish
    verbosity =0,   # 0 for no output, 1 for some output
    # batching=True,
    parsimony=0.001,
    populations=100,
    weight_randomize=0.2,
    weight_optimize=0.001,
    population_size=100,    # ^ Slightly larger populations, for greater diversity.
    ncycles_per_iteration=500,
    warm_start=False,  # No utilizar o modelo da rodada anterior
    elementwise_loss= elementwise_loss,  #  (mean square) can be changed to "L1DistLoss()" for mean absolute error, see link at the end for more options
    procs=0, #all processors
    turbo=True, # set to True to speed up the code
    early_stop_condition=("stop_if(loss, complexity) = loss < 1e-6 && complexity < 20"),# Stop early if we find a good and simple equation 
)

# %%
# Learn equations
model = PySRRegressor(
    niterations=niterations,  # for short runs, set this to a 100, for longer runs, set this to 10 million
    timeout_in_seconds=timeout_in_seconds,  # this line will make the code stop after 2 hours
    binary_operators=binary_operators, # activate this line to use simple ratio and normalized diference functions (comment the repvious line)
    # unary_operators=unary_operators, # other basic operators can be added here
    extra_sympy_mappings=extra_sympy_mappings, # here the format of the sought expressions are defined
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           2.367305
# 	1         0.126913                                 SR(NIR, 0.1697161)
# 	2         0.031098                        SR(NIR, Green + 0.10539818)
# 	3         0.088334       ID(ND(Green, 0.15829691), -0.08578538 / NIR)
# 	4         0.103482    ID(ND(Red, SR(Blue, Green)), -0.09456299 / NIR)
# 	5         0.073165  ID(ND(Green, SR(Blue, Red)), (-0.08793388 / NI...
# 	6         0.032538  ID(ND(Green, SR(Blue, Red)), NP((NIR - Blue) -...
# 	7         0.075428  ID(-0.6844888, SR(ID(ND(Red, Blue / Green), SR...
# 	8         0.071386  ID(-1.0717851, SR(Red + (ID(ND(Red, SR(Blue, G...
# 	9         0.002508  ID(NIR + -1.3325856, SR(Red + (0.07659062 * ID...
# 	10  >>>>  0.097958  ID(ND(Blue, ID(ID(CC(Blue, Green), -0.8341905)...
# 	11        0.008936  ID(ND(Blue, ID(ID(CC(Blue, Green), -0.8229501)...
# 	12        0.008817  ID(ND(Blue, ID(ID(CC(Blue, Green), -0.89580584...
# 	13        0.000385  ID(SR(ND(0.049011365, Blue / NIR), 3.5619876) ...
# 	14        0.020024  ID(((-0.019212184 / Blue) + ND(Green, ID(ID(CC...
# 	15        0.004500  ID((SR(-0.0203833, Blue) + ND(Green, ID(ID(CC(...
# 	16        0.001797  ID(ND(Green, ID(ID(CC(Blue, Green), -1.031966)...
# 	17        0.000441  ID(ND(Green, ID(ID(CC(Blue, Green), -1.031966)...
#
# 	        loss  complexity
# 	0   1.291319           1
# 	1   1.001839           3
# 	2   0.941428           5
# 	3   0.788971           7
# 	4   0.641472           9
# 	5   0.554150          11
# 	6   0.519236          13
# 	7   0.446528          15
# 	8   0.387118          17
# 	9   0.385181          19
# 	10  0.316650          21
# 	11  0.311041          23
# 	12  0.305604          25
# 	13  0.305369          27
# 	14  0.293381          29
# 	15  0.290753          31
# 	16  0.289709          33
# 	17  0.289454          35
# ]

# %% [markdown]
# We can print the model pareto curve, which will showcase the trend of discovered solutions:

# %%
best_score=model.get_best().score

# %%
# best scoring equation (not the one with the lowest loss nor the one with the lowest complexity, but the one that optimally balances the two)
scores = model.equations_.score
# get the index of the first max
# max_index = scores.idxmax(axis=0)
max_index = scores == best_score
max_index


pareto =model.equations_.iloc[:, [0, 1]] # Print the equations found
# pareto
plt.plot(pareto.complexity,pareto.loss,'-o')
plt.plot(pareto.complexity[max_index],pareto.loss[max_index],'ro',markersize=12)
plt.grid(True)
plt.xlabel("Complexity")
plt.ylabel("Loss (MSE)")



ii=0
# zip joins x and y coordinates in pairs
for p,q, in zip(pareto.complexity,pareto.loss):

    label = "{:.0f}".format(ii)

    plt.annotate(label, # this is the text
                 (p,q), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center') # horizontal alignment can be left, right or center
    ii=ii+1
plt.show()

# %% [markdown]
# We can also view the SymPy format of the equation of our interest:

# %%
unique_max_index = max_index[max_index].index.tolist()
model.sympy(unique_max_index[0])  # get the selected equation in sympy format
# Out:
# -15.51165680844*NIR/(-0.194065251723979 + (Blue/Green + Red)/(-Blue/Green + Red)) + (Blue - 0.158456406424203 + 1/(1.19876694831696 + (Blue + Green)/Blue))/(Blue + 0.158456406424203 - 1/(1.19876694831696 + (Blue + Green)/Blue))

# %%
expr = model.sympy(unique_max_index[0])

expr = sp.together(expr)
expr = sp.cancel(expr)
expr = sp.factor(expr)
expr = sp.simplify(expr)

# sp.pretty(expr)
expr
# Out:
# (12.9906274268047*Blue**3*NIR + 1.0*Blue**3 - 12.9906274268047*Blue**2*Green*NIR*Red + 5.90814203240064*Blue**2*Green*NIR + 0.674950340538276*Blue**2*Green*Red + 0.454800360158882*Blue**2*Green - 3.84969389315347*Blue**2*NIR + 0.296343953734679*Blue**2 - 5.90814203240064*Blue*Green**2*NIR*Red + 0.306967657966168*Blue*Green**2*Red + 3.84969389315347*Blue*Green*NIR*Red + 0.936182955097993*Blue*Green*NIR + 0.200017452489681*Blue*Green*Red - 0.0720660307112097*Blue*Green - 0.936182955097993*Green**2*NIR*Red - 0.0486409919697728*Green**2*Red)/(1.0*Blue**3 + 0.674950340538276*Blue**2*Green*Red + 0.454800360158882*Blue**2*Green - 0.296343953734679*Blue**2 + 0.306967657966168*Blue*Green**2*Red - 0.200017452489681*Blue*Green*Red + 0.0720660307112097*Blue*Green + 0.0486409919697728*Green**2*Red)

# %% [markdown]
# We can also view the form of any other expression in the list, using the index of it in `model.equations_`.

# %%
found_equations =model.equations_.iloc[:, [1,2]]  # print all the equations found
# pd.set_option('display.max_colwidth',200)  
# display(found_equations)

# Apply a color ramp to the 'Score' column
styled_df = found_equations.style.background_gradient(
    subset=['loss'],  # Column to apply gradient
    cmap='jet'      # Color map matplotlib colormap name
)

# Display in Jupyter Notebook
styled_df
# Out:
# <style type="text/css">
# #T_c2a53_row0_col0 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_c2a53_row1_col0 {
#   background-color: #ffb900;
#   color: #000000;
# }
# #T_c2a53_row2_col0 {
#   background-color: #f8f500;
#   color: #000000;
# }
# #T_c2a53_row3_col0 {
#   background-color: #7aff7d;
#   color: #000000;
# }
# #T_c2a53_row4_col0 {
#   background-color: #00e4f8;
#   color: #000000;
# }
# #T_c2a53_row5_col0 {
#   background-color: #008cff;
#   color: #f1f1f1;
# }
# #T_c2a53_row6_col0 {
#   background-color: #0068ff;
#   color: #f1f1f1;
# }
# #T_c2a53_row7_col0 {
#   background-color: #0020ff;
#   color: #f1f1f1;
# }
# #T_c2a53_row8_col0, #T_c2a53_row9_col0 {
#   background-color: #0000ed;
#   color: #f1f1f1;
# }
# #T_c2a53_row10_col0 {
#   background-color: #00009b;
#   color: #f1f1f1;
# }
# #T_c2a53_row11_col0 {
#   background-color: #000096;
#   color: #f1f1f1;
# }
# #T_c2a53_row12_col0, #T_c2a53_row13_col0 {
#   background-color: #000092;
#   color: #f1f1f1;
# }
# #T_c2a53_row14_col0 {
#   background-color: #000084;
#   color: #f1f1f1;
# }
# #T_c2a53_row15_col0, #T_c2a53_row16_col0, #T_c2a53_row17_col0 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c2a53">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2a53_level0_col0" class="col_heading level0 col0" >loss</th>
#       <th id="T_c2a53_level0_col1" class="col_heading level0 col1" >equation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2a53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2a53_row0_col0" class="data row0 col0" >1.291319</td>
#       <td id="T_c2a53_row0_col1" class="data row0 col1" >2.367305</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c2a53_row1_col0" class="data row1 col0" >1.001839</td>
#       <td id="T_c2a53_row1_col1" class="data row1 col1" >SR(NIR, 0.1697161)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c2a53_row2_col0" class="data row2 col0" >0.941428</td>
#       <td id="T_c2a53_row2_col1" class="data row2 col1" >SR(NIR, Green + 0.10539818)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c2a53_row3_col0" class="data row3 col0" >0.788971</td>
#       <td id="T_c2a53_row3_col1" class="data row3 col1" >ID(ND(Green, 0.15829691), -0.08578538 / NIR)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c2a53_row4_col0" class="data row4 col0" >0.641472</td>
#       <td id="T_c2a53_row4_col1" class="data row4 col1" >ID(ND(Red, SR(Blue, Green)), -0.09456299 / NIR)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c2a53_row5_col0" class="data row5 col0" >0.554150</td>
#       <td id="T_c2a53_row5_col1" class="data row5 col1" >ID(ND(Green, SR(Blue, Red)), (-0.08793388 / NIR) - Blue)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c2a53_row6_col0" class="data row6 col0" >0.519236</td>
#       <td id="T_c2a53_row6_col1" class="data row6 col1" >ID(ND(Green, SR(Blue, Red)), NP((NIR - Blue) - Blue, -0.14012277))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c2a53_row7_col0" class="data row7 col0" >0.446528</td>
#       <td id="T_c2a53_row7_col1" class="data row7 col1" >ID(-0.6844888, SR(ID(ND(Red, Blue / Green), SR(Red, Blue)) * 0.048684936, NIR))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c2a53_row8_col0" class="data row8 col0" >0.387118</td>
#       <td id="T_c2a53_row8_col1" class="data row8 col1" >ID(-1.0717851, SR(Red + (ID(ND(Red, SR(Blue, Green)), SR(0.044006087, Blue)) * 0.07798564), NIR))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c2a53_row9_col0" class="data row9 col0" >0.385181</td>
#       <td id="T_c2a53_row9_col1" class="data row9 col1" >ID(NIR + -1.3325856, SR(Red + (0.07659062 * ID(ND(Red, SR(Blue, Green)), SR(0.046824455, Blue))), NIR))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c2a53_row10_col0" class="data row10 col0" >0.316650</td>
#       <td id="T_c2a53_row10_col1" class="data row10 col1" >ID(ND(Blue, ID(ID(CC(Blue, Green), -0.8341905), 6.310884)), (ID(ND(Red, SR(Blue, Green)), 5.152906) / NIR) * 0.064467646)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c2a53_row11_col0" class="data row11 col0" >0.311041</td>
#       <td id="T_c2a53_row11_col1" class="data row11 col1" >ID(ND(Blue, ID(ID(CC(Blue, Green), -0.8229501), 6.357431)), (ID(ND(Red, Blue / Green), SR(0.28823844, Green)) * 0.06478659) / NIR)</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c2a53_row12_col0" class="data row12 col0" >0.305604</td>
#       <td id="T_c2a53_row12_col1" class="data row12 col1" >ID(ND(Blue, ID(ID(CC(Blue, Green), -0.89580584), 6.279691)), SR(ID(ND(Red, NP(1.6648756, Blue / Green)), 6.366026), NIR) * 0.06883528) - -0.3286206</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c2a53_row13_col0" class="data row13 col0" >0.305369</td>
#       <td id="T_c2a53_row13_col1" class="data row13 col1" >ID(SR(ND(0.049011365, Blue / NIR), 3.5619876) / Green, ID(ND(Red, CC(Blue, Green)), -5.1514225) * SR(0.07340854, (NIR - Blue) - Blue)) + -0.9332854</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c2a53_row14_col0" class="data row14 col0" >0.293381</td>
#       <td id="T_c2a53_row14_col1" class="data row14 col1" >ID(((-0.019212184 / Blue) + ND(Green, ID(ID(CC(Blue, Green), -1.0265567), 5.571699))) + 0.20349295, SR(ID(ND(Red, Blue / (Green - -0.019392319)), 5.5716944) * 0.06775846, NIR))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c2a53_row15_col0" class="data row15 col0" >0.290753</td>
#       <td id="T_c2a53_row15_col1" class="data row15 col1" >ID((SR(-0.0203833, Blue) + ND(Green, ID(ID(CC(Blue, Green), -1.0200428), 5.57816))) + 0.244879, SR(0.07378893, NIR - -0.04455012) * ID(ND(Red, Blue / (Green - -0.021419734)), 5.7557826))</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c2a53_row16_col0" class="data row16 col0" >0.289709</td>
#       <td id="T_c2a53_row16_col1" class="data row16 col1" >ID(ND(Green, ID(ID(CC(Blue, Green), -1.031966), 5.6004333)) + ((-0.019930601 / Blue) + 0.2494729), ((ID(ND(Red, Blue / (Green - -0.013050167)), -6.4217515) * 0.08448271) / NIR) - 0.010606468) - Blue</td>
#     </tr>
#     <tr>
#       <th id="T_c2a53_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c2a53_row17_col0" class="data row17 col0" >0.289454</td>
#       <td id="T_c2a53_row17_col1" class="data row17 col1" >ID(ND(Green, ID(ID(CC(Blue, Green), -1.031966), 5.6004333)) + ((-0.019930601 / Blue) + 0.2494729), ((ID(ND(Red, Blue / (Green - -0.013050167)), -6.4217515) * 0.08448271) / NIR) - 0.010606468) - (Blue * 0.795532)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Output

# %% [markdown]
# Plotting the first solutions

# %%
# "Viridis-like" colormap with white background
white_viridis = LinearSegmentedColormap.from_list('white_viridis', [
    (0, '#ffffff'),
    (1e-20, "#0004FF"),
    (0.2, "#0818F6"),
    (0.4, "#009d00"),
    (0.6, "#009d0a"),
    (0.8, "#fcfc01"),
    (1, "#f2ff00"),
], N=256)


num_eq = len(model.equations_)

fig_rows = int(np.ceil(num_eq / 4))
fig_cols = 4

fig, axes = plt.subplots(
    fig_rows,
    fig_cols,
    figsize=(3 * fig_cols, 3 * fig_rows),
    sharey=True,
    sharex=True,
    subplot_kw=dict(projection="scatter_density"),
)

axes = axes.flatten()
it = model.equations_.index  # safer than linspace

for ax, i in zip(axes, it):

    # Predict
    ypredict_simpler = np.asarray(model.predict(X, index=i)).ravel()
    ytrue = np.asarray(y).ravel()

    #  REQUIRED: mask non-finite values
    mask = np.isfinite(ypredict_simpler) & np.isfinite(ytrue)

    # Skip unstable equations
    if mask.sum() < 0.7 * len(ytrue):
        ax.set_visible(False)
        continue

    yp = ypredict_simpler[mask]
    yt = ytrue[mask]

    #  scatter_density WITH your colormap
    density = ax.scatter_density(yp, yt, cmap=white_viridis)

    ax.plot([0, 6], [0, 6], linestyle="--", color="k", linewidth=0.5)

    #  metrics must use masked values
    mse = mean_squared_error(yt, yp)
    r2 = r2_score(yt, yp)

    ax.set_title(f"PySR Eq {i}\nMSE: {mse:.1f}, R2: {r2:.2f}")
    ax.set_xlabel("Modeled")
    ax.set_ylabel("Measured")

    ax.set_xlim(0, 6)
    ax.set_ylim(0, 6)
    ax.set_aspect("equal")
    ax.grid(True)

    fig.colorbar(density, ax=ax, label="Number points")

# Hide unused axes if any
for ax in axes[len(it):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(
    fig_rows, fig_cols,
    figsize=(3 * fig_cols, 3 * fig_rows),
    sharey=True,
    sharex=True
)

bin_interval = 0.2
bins = np.arange(-2, 2 + bin_interval, bin_interval)

axes = axes.flatten()
it = model.equations_.index  # safer than linspace

for ax, i in zip(axes, it):

    # Predict
    ypred = np.asarray(model.predict(X, index=i)).ravel()
    ytrue = np.asarray(y).ravel()

    #  REQUIRED masking
    mask = np.isfinite(ypred) & np.isfinite(ytrue)

    # Skip unstable equations
    if mask.sum() < 0.7 * len(ytrue):
        ax.set_visible(False)
        continue

    residuals = ypred[mask] - ytrue[mask]

    # Histogram
    ax.hist(residuals, bins=bins, density=True, rwidth=0.8)

    ax.set_xlabel("Eq residual (var units)")
    ax.set_ylabel("Density")
    ax.grid(True)

    #  Correct statistics
    mean = residuals.mean()
    std = residuals.std(ddof=1)
    r2 = r2_score(ytrue[mask], ypred[mask])

    valid_frac = mask.mean()

    ax.set_title(
        f"PySR Eq {i}\n"
        f"std: {std:.2f}, R2: {r2:.2f}\n"
        f"valid: {valid_frac:.0%}"
    )

# Hide unused axes
for ax in axes[len(it):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# Create a Taylor diagram with labeled data points and modified axes

# %%
import numpy as np
import pandas as pd
import skill_metrics as sm

# number of equations
n_e = len(found_equations)

eq_indices = model.equations_.index  # safer than linspace

# Reference data
yref = np.asarray(y).ravel()

# Prepare arrays for Taylor diagram
sdev = []
crmsd = []
ccoef = []

# --- Reference point ---
ref_stats = sm.taylor_statistics(yref, yref)
sdev.append(ref_stats["sdev"][0])
crmsd.append(ref_stats["crmsd"][0])
ccoef.append(ref_stats["ccoef"][0])

labels = ["Reference"]

# --- Model equations ---
for i in eq_indices:

    ypred = np.asarray(model.predict(X, index=i)).ravel()

    #  REQUIRED masking
    mask = np.isfinite(ypred) & np.isfinite(yref)

    # Skip unstable equations
    if mask.sum() < 0.7 * len(yref):
        continue

    stats = sm.taylor_statistics(ypred[mask], yref[mask])

    sdev.append(stats["sdev"][1])
    crmsd.append(stats["crmsd"][1])
    ccoef.append(stats["ccoef"][1])

    labels.append(f"Eq {i}")

# Convert to arrays
sdev = np.asarray(sdev)
crmsd = np.asarray(crmsd)
ccoef = np.asarray(ccoef)

# --- Taylor Diagram ---
intervalsCOR = np.concatenate((np.arange(0, 1.0, 0.2), [0.9, 0.95, 0.99, 1]))

sm.taylor_diagram(
    sdev,
    crmsd,
    ccoef,
    markerLabel=labels,
    markerLabelColor="b",
    tickRMS=np.arange(0, 2, 0.5),
    tickRMSangle=110.0,
    colRMS="m",
    styleRMS=":",
    widthRMS=2.0,
    tickSTD=np.arange(0, 2, 0.2),
    axismax=2.0,
    colSTD="b",
    styleSTD="-.",
    widthSTD=1.0,
    colCOR="k",
    styleCOR="--",
    widthCOR=1.0,
)

# %% [markdown]
# # Other PySR Options

# %% [markdown]
# The full list of PySR parameters can be found here: https://ai.damtp.cam.ac.uk/pysr/api
