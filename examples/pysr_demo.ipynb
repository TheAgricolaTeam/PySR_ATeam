# %% [markdown]
# # Setup

# %% [markdown]
# ## Instructions
# 1. Work on a copy of this notebook: _File_ > _Save a copy in Drive_ (you will need a Google account).
# 2. (Optional) If you would like to do the deep learning component of this tutorial, turn on the GPU with Edit->Notebook settings->Hardware accelerator->GPU

# %% [markdown]
# !pip install -U pysr

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Simple PySR example:

# %% [markdown]
# First, let's learn a simple function
#
# $$2.5382 \cos(x3) + x0^2 - 2$$

# %%
# Dataset
np.random.seed(0)
X = 2 * np.random.randn(100, 5)
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 2

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %% [markdown]
# PySR can run for arbitrarily long, and continue to find more and more accurate expressions. You can set the total number of cycles of evolution with `niterations`, although there are also a [few more ways](https://github.com/MilesCranmer/PySR/pull/134) to stop execution.
#
# **This first execution will take a bit longer to startup, as the library is JIT-compiled. The next execution will be much faster.**

# %%
# Learn equations
model = PySRRegressor(
    niterations=30,
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin"],
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 4.950e+04
# Progress: 317 / 900 total iterations (35.222%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  0.000e+00  y = 2.3552
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.108e+00  3.394e-01  y = (x₀ * x₀) + -1.5049
# 7           3.030e+00  1.285e-02  y = ((x₀ * 0.97769) * x₀) + -1.6641
# 9           3.015e+00  2.401e-03  y = ((x₀ * 0.975) + -1.3047) * (x₀ + 1.2764)
# 11          2.983e+00  5.414e-03  y = (exp(sin((x₀ + -3.1947) * 0.50164)) * 13.405) + -6.085...
#                                       1
# 13          2.969e+00  2.325e-03  y = (exp(sin(((x₀ + x₀) + -6.6325) * 0.24069)) * 14.511) +...
#                                        -6.4806
# 18          8.143e-01  2.587e-01  y = (((cos(x₃) * 0.31725) + exp(sin((x₀ + (x₀ + -5.5192)) ...
#                                       * 0.28338))) * 9.6578) + -4.7379
# 20          6.773e-01  9.212e-02  y = (((cos(x₃) * (-0.15596 * -1.5762)) + exp(sin((x₀ + (x₀...
#                                        + -5.5192)) * 0.28338))) * 9.6578) + -4.7379
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.910e+04
# Progress: 832 / 900 total iterations (92.444%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  0.000e+00  y = 2.3552
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.045e+00  3.496e-01  y = (x₀ * x₀) + -1.7557
# 7           3.030e+00  2.620e-03  y = ((x₀ * 0.97769) * x₀) + -1.6641
# 8           1.118e+00  9.964e-01  y = (cos(x₃) + -1.852) + (x₀ * x₀)
# 9           9.515e-01  1.617e-01  y = ((x₀ * x₀) + -3.1192) + exp(cos(x₃))
# 10          1.908e-13  2.924e+01  y = ((x₀ * x₀) + (cos(x₃) * 2.5382)) + -2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  0.000e+00  y = 2.3552
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.045e+00  3.496e-01  y = (x₀ * x₀) + -1.7557
# 7           3.030e+00  2.620e-03  y = ((x₀ * 0.97769) * x₀) + -1.6641
# 8           1.118e+00  9.964e-01  y = (cos(x₃) + -1.852) + (x₀ * x₀)
# 9           9.515e-01  1.617e-01  y = ((x₀ * x₀) + -3.1192) + exp(cos(x₃))
# 10          1.908e-13  2.924e+01  y = ((x₀ * x₀) + (cos(x₃) * 2.5382)) + -2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# PySRRegressor.equations_ = [
# 	   pick      score                                 equation          loss  \
# 	0         0.000000                                2.3552127  3.360272e+01
# 	1         0.850855                                  x0 * x0  6.128180e+00
# 	2         0.349618                   (x0 * x0) + -1.7557017  3.045492e+00
# 	3         0.002620    ((x0 * 0.97769153) * x0) + -1.6640513  3.029573e+00
# 	4         0.996444       (cos(x3) + -1.8519732) + (x0 * x0)  1.118488e+00
# 	5         0.161678  ((x0 * x0) + -3.1192057) + exp(cos(x3))  9.515150e-01
# 	6  >>>>  29.238049  ((x0 * x0) + (cos(x3) * 2.5382)) + -2.0  1.907622e-13
#
# 	   complexity
# 	0           1
# 	1           3
# 	2           5
# 	3           7
# 	4           8
# 	5           9
# 	6          10
# ]
#   - outputs/20260227_201114_YFfir1/hall_of_fame.csv

# %% [markdown]
# We can print the model, which will print out all the discovered expressions:

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	   pick      score                                 equation          loss  \
# 	0         0.000000                                2.3552127  3.360272e+01
# 	1         0.850855                                  x0 * x0  6.128180e+00
# 	2         0.349618                   (x0 * x0) + -1.7557017  3.045492e+00
# 	3         0.002620    ((x0 * 0.97769153) * x0) + -1.6640513  3.029573e+00
# 	4         0.996444       (cos(x3) + -1.8519732) + (x0 * x0)  1.118488e+00
# 	5         0.161678  ((x0 * x0) + -3.1192057) + exp(cos(x3))  9.515150e-01
# 	6  >>>>  29.238049  ((x0 * x0) + (cos(x3) * 2.5382)) + -2.0  1.907622e-13
#
# 	   complexity
# 	0           1
# 	1           3
# 	2           5
# 	3           7
# 	4           8
# 	5           9
# 	6          10
# ]

# %% [markdown]
# We can also view the SymPy format of the best expression:

# %%
model.sympy()
# Out:
# x0*x0 + cos(x3)*2.5382 - 2.0

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
model.sympy(2)
# Out:
# x0*x0 - 1.7557017

# %% [markdown]
# ## Output

# %% [markdown]
# `model.equations_` is a Pandas DataFrame. We can export the results in various ways:

# %%
model.latex()
# Out:
# 'x_{0} x_{0} + \\cos{\\left(x_{3} \\right)} 2.54 - 2.00'

# %% [markdown]
# These is also `model.sympy(), model.jax(), model.pytorch()`. All of these can take an index as input, to get the result for an arbitrary equation in the list.
#
# We can also use `model.predict` for arbitrary equations, with the default equation being the one chosen by `model_selection`:

# %%
ypredict = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(ypredict - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 0.0
# Manual selection MSE for index 2: 3.045492017148654

# %% [markdown]
# # Custom operators

# %% [markdown]
# A full list of operators is given here: https://ai.damtp.cam.ac.uk/pysr/operators,
# but we can also use any binary or unary operator in `julia`, or define our own as arbitrary functions.
#
# Say that we want a command to do quartic powers:
#
# $$ y = x_0^4 - 2 $$

# %%
y = X[:, 0] ** 4 - 2

# %% [markdown]
# We can do this by passing a string in Julia syntax.
#
# We also define the operator in sympy, with `extra_sympy_mappings`, to enable its use in `predict`, and other export functions.

# %%
model = PySRRegressor(
    niterations=5,
    populations=40,
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin", "quart(x) = x^4"],
    extra_sympy_mappings={"quart": lambda x: x**4},
)
model.fit(X, y)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.590e+04  0.000e+00  y = 46.898
# 2           4.000e+00  8.287e+00  y = quart(x₀)
# 4           9.194e-11  1.225e+01  y = quart(x₀) + -2
# 8           9.161e-11  9.031e-04  y = (quart(x₀) + -2) + (x₀ * 1.3462e-06)
# 10          7.506e-11  9.965e-02  y = (quart(x₀) + -1.897) + ((x₄ * 7.6054e-07) + -0.103)
# 11          6.172e-11  1.957e-01  y = (((exp(x₁) * 2.7942e-07) * x₀) + quart(x₀)) + -2
# 12          4.297e-11  3.621e-01  y = (quart(x₀) + -2) + (quart(x₀) * (sin(x₄) * -1.0051e-07...
#                                       ))
# 17          4.254e-11  1.988e-03  y = ((-1.0499e-07 * (quart(x₀) * sin(sin(x₁ + -1.9386) * x...
#                                       ₄))) + -2) + quart(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          46.897507
# 	1         8.288017                                          quart(x0)
# 	2        12.248075                             quart(x0) + -1.9999999
# 	3         0.000903     (quart(x0) + -1.9999996) + (x0 * 1.3462308e-6)
# 	4         0.099649  (quart(x0) + -1.8970019) + ((x4 * 7.6054084e-7...
# 	5         0.195717  (((exp(x1) * 2.794176e-7) * x0) + quart(x0)) +...
# 	6  >>>>   0.362052  (quart(x0) + -1.9999996) + (quart(x0) * (sin(x...
# 	7         0.001988  ((-1.04989006e-7 * (quart(x0) * sin(sin(x1 + -...
#
# 	           loss  complexity
# 	0  1.590376e+04           1
# 	1  3.999999e+00           2
# 	2  9.194270e-11           4
# 	3  9.161118e-11           8
# 	4  7.505754e-11          10
# 	5  6.171571e-11          11
# 	6  4.296931e-11          12
# 	7  4.254422e-11          17
# ]
#   - outputs/20260227_201259_9Z8JQK/hall_of_fame.csv

# %%
model.sympy()
# Out:
# x0**4*sin(x4)*(-1.0051335e-7) + x0**4 - 1.9999996

# %% [markdown]
# Since `quart` is arguably more complex than the other operators, you can also give it a different complexity, using, e.g., `complexity_of_operators={"quart": 2}` to give it a complexity of 2 (instead of the default 1). You can also define custom complexities for variables and constants (`complexity_of_variables` and `complexity_of_constants`, respectively - both take a single number).
#
#
# One can also add a binary operator, with, e.g., `"myoperator(x, y) = x^2 * y"`. All Julia operators that work on scalar 32-bit floating point values are available.
#
# Make sure that any operator you add is valid over the real line. So, e.g., you will need to define `"mysqrt(x) = sqrt(abs(x))"` to enable it for negative numbers,
# or, simply have it return a very large number for bad inputs (to prevent negative input in a soft way):
# `"mysqrt(x::T) where {T} = (x >= 0) ? x : T(-1e9)"` (Julia syntax for a template function of input type `T`), which will make `mysqrt(x)` return -10^9 for negative x–hurting the loss of the equation.

# %% [markdown]
# ## Scoring

# %% [markdown]
# Using `model_selection="best"`selects the equation with the max score and prints it. But in practice it is best to look through all the equations manually, select an equation above some MSE threshold, and then use the score to select among that loss threshold.
#
# Here, "score" is defined by:
# $$ \text{score} = - \log(\text{loss}_i/\text{loss}_{i-1})/
# (\text{complexity}_i - \text{complexity}_{i-1})$$

# %% [markdown]
# This scoring is motivated by the common strategy of looking for drops in the loss-complexity curve.
#
# From Schmidt & Lipson (2009) -

# %% [markdown]
# ![F4.large.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Noise example

# %% [markdown]
# Here is an example with noise. Known Gaussian noise with $\sigma$ between 0.1 and 5.0. We record samples of $y$:
#
# $$ \sigma \sim U(0.1, 5.0) $$
# $$ \epsilon \sim \mathcal{N}(0, \sigma^2)$$
# $$ y = 5\;\cos(3.5 x_0) - 1.3 + \epsilon.$$
# We have 5 features, say. The weights change the loss function to be:
# $$MSE = \sum [(y - f(x))^2*w],$$
#
# so in this example, we can set:
# $$w = 1/\sigma^2.$$

# %%
np.random.seed(0)
N = 3000
upper_sigma = 5
X = 2 * np.random.rand(N, 5)
sigma = np.random.rand(N) * (5 - 0.1) + 0.1
eps = sigma * np.random.randn(N)
y = 5 * np.cos(3.5 * X[:, 0]) - 1.3 + eps

# %% [markdown]
# Let's look at this dataset:

# %%
plt.scatter(X[:, 0], y, alpha=0.2)
plt.xlabel("$x_0$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# Define some weights to use:

# %%
weights = 1 / sigma**2

# %%
weights[:5]
# Out:
# array([0.25199296, 0.0775419 , 0.11515701, 0.1781281 , 0.0448131 ])

# %% [markdown]
# Let's run PySR again:

# %%
model = PySRRegressor(
    elementwise_loss="myloss(x, y, w) = w * abs(x - y)",  # Custom loss function with weights.
    niterations=20,
    populations=20,  # Use more populations
    binary_operators=["+", "*"],
    unary_operators=["cos"],
)
model.fit(X, y, weights=weights)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 3.400e+03
# Progress: 58 / 400 total iterations (14.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  0.000e+00  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0869
# 4           2.743e+00  1.488e-01  y = cos(x₀ * -3.3337)
# 6           1.781e+00  2.161e-01  y = cos(x₀) * (x₀ * -8.384)
# 8           1.701e+00  2.277e-02  y = ((x₀ * cos(x₀)) * -9.2778) + 0.75578
# 10          1.313e+00  1.294e-01  y = (cos((x₀ * 3.5265) + 0.22384) * 3.644) + -1.605
# 12          7.974e-01  2.495e-01  y = (x₀ * -0.26334) + ((cos(x₀ * 3.5265) * 5.0857) + -0.35...
#                                       208)
# 14          3.127e-01  4.681e-01  y = (((x₄ * 0.0043035) + (cos(x₀ * 3.4949) * 4.3992)) * 1....
#                                       1427) + -1.2837
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.500e+04
# Progress: 160 / 400 total iterations (40.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  0.000e+00  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0869
# 4           2.743e+00  1.488e-01  y = cos(x₀ * -3.3337)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * -3.2919) * 5.0195
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4967) + -0.25661) * 5.0311
# 10          3.126e-01  7.272e-06  y = (cos(x₀ * -3.4955) * (5.0362 + -0.0057522)) + -1.2868
# 12          3.113e-01  2.080e-03  y = (cos((x₀ * 3.486) + (x₄ * 0.0091944)) * 5.0223) + -1.2...
#                                       594
# 17          3.113e-01  3.624e-06  y = (cos(0.0091944 * x₀) * (cos((x₀ * 3.486) + (x₄ * 0.009...
#                                       1944)) * 5.0223)) + -1.2594
# 19          3.112e-01  7.994e-05  y = (cos((-3.6852 + x₄) * 0.0091944) * (5.0223 * cos((x₀ *...
#                                        3.486) + (x₄ * 0.0091944)))) + -1.2594
# 21          3.106e-01  1.065e-03  y = ((cos((x₄ + -3.685) * (x₀ * 0.019681)) * cos((x₀ * 3.4...
#                                       885) + (x₄ * 0.0079101))) * 5.0368) + -1.2649
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.900e+04
# Progress: 312 / 400 total iterations (78.000%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  0.000e+00  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0869
# 4           2.743e+00  1.488e-01  y = cos(x₀ * -3.3337)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * -3.2919) * 5.0195
# 8           3.126e-01  6.242e-01  y = (cos(x₀ * 3.4967) + -0.25661) * 5.0311
# 10          3.126e-01  7.272e-06  y = (cos(x₀ * -3.4955) * (5.0362 + -0.0057522)) + -1.2868
# 12          3.102e-01  3.892e-03  y = (cos(((x₂ * 0.015679) + 3.4803) * x₀) * 5.0343) + -1.2...
#                                       806
# 14          3.069e-01  5.355e-03  y = (cos((((x₄ * x₂) * 0.013507) + 3.4827) * x₀) * 5.03) +...
#                                        -1.2741
# 18          3.068e-01  7.302e-06  y = (cos(x₀ * (((((x₄ + x₀) * x₂) + -0.52984) * 0.0075369)...
#                                        + 3.483)) * 5.0242) + -1.28
# 30          3.060e-01  2.204e-04  y = (cos(x₀ * (((((((x₄ + (x₂ + x₃)) * x₂) * ((x₀ * x₀) * ...
#                                       0.083947)) + x₂) * (x₄ + x₀)) * 0.0039991) + 3.4783)) * 5....
#                                       024) + -1.2718
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  0.000e+00  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0869
# 4           2.743e+00  1.488e-01  y = cos(x₀ * -3.3337)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * -3.2919) * 5.0195
# 8           3.126e-01  6.243e-01  y = (cos(x₀ * -3.4956) * 5.0307) + -1.2871
# 12          3.099e-01  2.165e-03  y = (cos(((x₂ * 0.014441) + 3.4845) * x₀) * 5.0211) + -1.2...
#                                       913
# 14          3.069e-01  4.914e-03  y = (cos((((x₄ * x₂) * 0.013507) + 3.4827) * x₀) * 5.03) +...
#                                        -1.2741
# 18          3.064e-01  3.379e-04  y = (cos(x₀ * ((x₂ * (((x₄ * 2.536) + x₀) * 0.0039379)) + ...
#                                       3.4809)) * 5.0245) + -1.2747
# 22          3.060e-01  3.678e-04  y = -1.2718 + (5.024 * cos((3.4783 + (0.0039991 * (x₂ + ((...
#                                       x₀ * (0.45321 + (x₂ + x₂))) * x₄)))) * x₀))
# 24          3.059e-01  1.099e-04  y = -1.2718 + (5.024 * cos(x₀ * (3.4783 + (((((x₂ * x₂) + ...
#                                       (x₀ * (0.45321 + x₂))) * x₄) + 1.0926) * 0.0039991))))
# 28          3.057e-01  1.726e-04  y = (cos(((((((((x₄ + x₂) + x₃) * x₂) * x₀) * (x₀ * 0.0589...
#                                       2)) + x₂) * (x₄ * 0.010577)) + 3.4817) * x₀) * 5.0385) + -...
#                                       1.2778
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         -1.1848763
# 	1         0.018599                                     x0 + -2.086941
# 	2         0.148813                               cos(x0 * -3.3337047)
# 	3         0.461756                     cos(x0 * -3.291873) * 5.019505
# 	4   >>>>  0.624258     (cos(x0 * -3.4956288) * 5.030725) + -1.2870582
# 	5         0.002165  (cos(((x2 * 0.014440511) + 3.4845202) * x0) * ...
# 	6         0.004914  (cos((((x4 * x2) * 0.01350709) + 3.482661) * x...
# 	7         0.000338  (cos(x0 * ((x2 * (((x4 * 2.5359988) + x0) * 0....
# 	8         0.000368  -1.2717891 + (5.0240464 * cos((3.4782927 + (0....
# 	9         0.000110  -1.2717891 + (5.0240464 * cos(x0 * (3.4782927 ...
# 	10        0.000173  (cos(((((((((x4 + x2) + x3) * x2) * x0) * (x0 ...
#
# 	        loss  complexity
# 	0   3.304065           1
# 	1   3.183421           3
# 	2   2.743251           4
# 	3   1.089406           6
# 	4   0.312584           8
# 	5   0.309889          12
# 	6   0.306858          14
# 	7   0.306443          18
# 	8   0.305993          22
# 	9   0.305926          24
# 	10  0.305715          28
# ]
#   - outputs/20260227_201426_2g3YSA/hall_of_fame.csv

# %% [markdown]
# Let's see if we get similar results to the true equation

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         -1.1848763
# 	1         0.018599                                     x0 + -2.086941
# 	2         0.148813                               cos(x0 * -3.3337047)
# 	3         0.461756                     cos(x0 * -3.291873) * 5.019505
# 	4   >>>>  0.624258     (cos(x0 * -3.4956288) * 5.030725) + -1.2870582
# 	5         0.002165  (cos(((x2 * 0.014440511) + 3.4845202) * x0) * ...
# 	6         0.004914  (cos((((x4 * x2) * 0.01350709) + 3.482661) * x...
# 	7         0.000338  (cos(x0 * ((x2 * (((x4 * 2.5359988) + x0) * 0....
# 	8         0.000368  -1.2717891 + (5.0240464 * cos((3.4782927 + (0....
# 	9         0.000110  -1.2717891 + (5.0240464 * cos(x0 * (3.4782927 ...
# 	10        0.000173  (cos(((((((((x4 + x2) + x3) * x2) * x0) * (x0 ...
#
# 	        loss  complexity
# 	0   3.304065           1
# 	1   3.183421           3
# 	2   2.743251           4
# 	3   1.089406           6
# 	4   0.312584           8
# 	5   0.309889          12
# 	6   0.306858          14
# 	7   0.306443          18
# 	8   0.305993          22
# 	9   0.305926          24
# 	10  0.305715          28
# ]

# %% [markdown]
# We can also filter all equations up to 2x the most accurate equation, then select the best score from that list:

# %%
best_idx = model.equations_.query(
    f"loss < {2 * model.equations_.loss.min()}"
).score.idxmax()
model.sympy(best_idx)
# Out:
# cos(x0*(-3.4956288))*5.030725 - 1.2870582

# %% [markdown]
# We can also use `denoise=True`, which will run the input through a Gaussian process to denoise the dataset, before fitting on it.

# %% [markdown]
# Let's look at the fit:

# %%
plt.scatter(X[:, 0], y, alpha=0.1)
y_prediction = model.predict(X, index=best_idx)
plt.scatter(X[:, 0], y_prediction)

# %% [markdown]
# # Multiple outputs

# %% [markdown]
# For multiple outputs, multiple equations are returned:

# %%
X = 2 * np.random.randn(100, 5)
y = 1 / X[:, [0, 1, 2]]

# %%
model = PySRRegressor(
    binary_operators=["+", "*"],
    unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
)
model.fit(X, y)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 5.140e+04
# Progress: 319 / 9300 total iterations (3.430%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.882e-14  1.393e-02  y₀ = inv(x₀) + 0
# 10          2.541e-14  7.065e-02  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  0.000e+00  y₁ = -0.22155
# 2           2.336e-12  3.324e+01  y₁ = inv(x₁)
# 6           2.336e-12  7.153e-07  y₁ = inv(x₁) + (x₁ * -2.516e-09)
# 9           7.609e-15  1.909e+00  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           2.991e-13  3.105e+00  y₂ = inv(x₂) + -5.9605e-07
# 6           6.788e-15  1.893e+00  y₂ = inv(x₂ + (x₃ * -5.3117e-11))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.710e+04
# Progress: 787 / 9300 total iterations (8.462%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.809e-14  2.340e-02  y₀ = inv(x₀) + 1.4901e-08
# 7           3.210e-14  5.704e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 10          2.541e-14  7.794e-02  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# 26          2.198e-14  9.047e-03  y₀ = inv(x₀) + (inv((x₀ * (-0.91655 * (-0.44582 + (((-0.7...
#                                        9968 * x₄) + -3.3464) * (inv(x₁) * 0.51483))))) * (x₄ + x...
#                                        ₄)) * -6.475e-09)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  0.000e+00  y₁ = -0.22247
# 2           2.336e-12  3.324e+01  y₁ = inv(x₁)
# 6           2.336e-12  7.153e-07  y₁ = inv(x₁) + (x₁ * -2.516e-09)
# 7           2.335e-12  2.405e-04  y₁ = (inv(x₂) * -2.5502e-10) + inv(x₁)
# 9           7.609e-15  2.863e+00  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 12          7.589e-15  8.765e-04  y₁ = (((x₄ * (x₂ + -1.2464)) * 4.055e-09) + 1) * inv(x₁)
# 16          7.041e-15  1.875e-02  y₁ = (inv(x₁) * ((inv(x₁) * 1.7722e-10) + 1)) + ((x₂ + in...
#                                        v(x₂)) * -1.6734e-10)
# 24          7.039e-15  3.942e-05  y₁ = ((inv(x₁) * 1.7722e-10) + 1) * (inv(x₁) + ((inv(x₂) ...
#                                        + ((x₄ * (x₁ * (x₃ + x₃))) + -0.095494)) * -1.6734e-10))
# 26          7.032e-15  4.734e-04  y₁ = inv(x₁) * ((((((x₀ + (x₁ * (x₁ * -0.53991))) * 1.772...
#                                        2e-10) * (0.84589 + inv(x₂))) * x₃) + 1) + (inv(x₁) * 1.7...
#                                        722e-10))
# 30          7.030e-15  7.896e-05  y₁ = (inv(x₁) * ((inv(x₁) * 1.7722e-10) + 1)) + ((x₃ * 1....
#                                        7722e-10) * ((((inv(x₂) + x₁) * (x₀ + (x₁ + -1.0145))) * ...
#                                        x₀) + (x₁ + x₁)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           2.991e-13  3.105e+00  y₂ = inv(x₂) + -5.9605e-07
# 6           6.788e-15  1.893e+00  y₂ = inv(x₂ + (x₃ * -5.3117e-11))
# 10          5.613e-15  4.750e-02  y₂ = inv(x₂) * (1 + ((x₄ + 9.9669) * 3.7253e-09))
# 14          5.438e-15  7.937e-03  y₂ = (((((x₀ + x₄) + 9.2952) + 1) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# 18          4.663e-15  3.844e-02  y₂ = inv(x₂) * ((((inv(inv(x₃)) * 0.4536) + inv(inv(x₄ + ...
#                                        10.519))) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.080e+04
# Progress: 1310 / 9300 total iterations (14.086%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.809e-14  2.340e-02  y₀ = inv(x₀) + 1.4901e-08
# 7           3.210e-14  5.704e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 9           3.082e-14  2.033e-02  y₀ = inv((inv(x₁ + -0.061777) * -5.707e-11) + x₀)
# 10          2.541e-14  1.932e-01  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# 12          2.531e-14  1.970e-03  y₀ = (x₁ * 0.29809) + inv(inv((x₁ * -0.29809) + inv(x₀)))
# 14          2.517e-14  2.639e-03  y₀ = inv(inv((x₁ * -0.29809) + inv(x₀))) + ((x₁ * 0.29809...
#                                        ) + -3.9003e-09)
# 21          2.172e-14  2.105e-02  y₀ = inv(x₀ + inv((x₀ + -0.069029) * inv((x₀ + ((x₀ * inv...
#                                        (x₁ + x₂)) * -0.069029)) * -2.2226e-09)))
# 29          2.172e-14  5.111e-05  y₀ = inv(inv((x₀ + -0.069029) * inv((((inv(2.471 * (inv(x...
#                                        ₀) + -2.2226e-09)) * inv(x₂ + x₁)) * (x₀ * x₃)) + x₀) * -...
#                                        2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  0.000e+00  y₁ = -0.22247
# 2           2.336e-12  3.324e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           3.262e-14  4.271e+00  y₁ = inv(x₁) + (inv(x₁) * -4.5952e-08)
# 8           8.311e-15  1.367e+00  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 12          7.538e-15  3.127e-03  y₁ = ((x₄ * ((-1.3176 + x₀) * 3.3836e-09)) + 1) * inv(x₁)
# 14          7.041e-15  3.413e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 16          6.730e-15  2.258e-02  y₁ = (((((x₄ * x₂) * -1.1735e-09) * (x₀ + 1.0531)) + 1) *...
#                                         inv(x₁)) + -2.2753e-09
# 19          6.517e-15  1.073e-02  y₁ = ((1.9475e-10 * inv(x₁)) + (1 + (((x₄ * (x₂ * -1.4139...
#                                        e-09)) * 2.2551) + -2.1865e-08))) * inv(x₁)
# 21          6.499e-15  1.365e-03  y₁ = (((inv(x₁) * 1.9475e-10) + ((x₄ * ((x₂ * -1.4139e-09...
#                                        ) * (2.2551 + x₁))) + -2.1865e-08)) + 1) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.663e-15  4.657e-02  y₂ = (((((x₄ + x₄) + x₃) + 13.064) * 3.7253e-09) + 1) * i...
#                                        nv(x₂)
# 17          3.881e-15  6.116e-02  y₂ = inv(x₂) * ((((x₄ + 0.31172) + (inv(x₀ * -2.031) + 9....
#                                        4079)) * 3.7253e-09) + 1)
# 19          3.162e-15  1.025e-01  y₂ = inv(x₂) * ((((x₄ + (x₀ + 0.72393)) + (inv(x₀ * -2.03...
#                                        1) + 9.4079)) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.530e+04
# Progress: 1802 / 9300 total iterations (19.376%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.809e-14  2.340e-02  y₀ = inv(x₀) + 1.4901e-08
# 7           3.210e-14  5.704e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 9           3.082e-14  2.033e-02  y₀ = inv((inv(x₁ + -0.061777) * -5.707e-11) + x₀)
# 10          2.541e-14  1.932e-01  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# 12          2.531e-14  1.970e-03  y₀ = (x₁ * 0.29809) + inv(inv((x₁ * -0.29809) + inv(x₀)))
# 14          2.517e-14  2.639e-03  y₀ = inv(inv((x₁ * -0.29809) + inv(x₀))) + ((x₁ * 0.29809...
#                                        ) + -3.9003e-09)
# 21          2.172e-14  2.105e-02  y₀ = inv(x₀ + inv((x₀ + -0.069029) * inv((x₀ + ((x₀ * inv...
#                                        (x₁ + x₂)) * -0.069029)) * -2.2226e-09)))
# 23          1.320e-14  2.492e-01  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + ((((x₀ * x₂) + ...
#                                        0.33284) * inv(x₂)) * -0.069029)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  0.000e+00  y₁ = -0.22247
# 2           2.336e-12  3.324e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           3.262e-14  4.271e+00  y₁ = inv(x₁) + (inv(x₁) * -4.5952e-08)
# 8           8.311e-15  1.367e+00  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 12          7.538e-15  3.127e-03  y₁ = ((x₄ * ((-1.3176 + x₀) * 3.3836e-09)) + 1) * inv(x₁)
# 14          7.041e-15  3.413e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 15          6.517e-15  7.734e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 21          6.499e-15  4.549e-04  y₁ = (((inv(x₁) * 1.9475e-10) + ((x₄ * ((x₂ * -1.4139e-09...
#                                        ) * (2.2551 + x₁))) + -2.1865e-08)) + 1) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 19          3.126e-15  1.179e-02  y₂ = inv(x₂) * (((((x₄ + x₀) * 0.61785) + (inv(x₀ * -2.03...
#                                        1) + 9.4079)) * 3.7253e-09) + 1)
# 21          3.102e-15  3.922e-03  y₂ = inv(x₂) * (((((x₄ + x₀) * (x₂ + 0.61785)) + (inv(x₀ ...
#                                        * -2.031) + 9.4079)) * 3.7253e-09) + 1)
# 22          2.960e-15  4.690e-02  y₂ = inv(x₂) * ((((((x₂ + 0.61785) * (x₄ + x₀)) + inv(x₀ ...
#                                        * inv(-0.46921))) + 9.4079) * 3.7253e-09) + 1)
# 23          2.673e-15  1.018e-01  y₂ = inv(x₂) * ((((inv(-2.031 * x₀) + ((x₂ + x₄) + (x₂ * ...
#                                        x₄))) + (0.72393 + 9.4079)) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.080e+05
# Progress: 2287 / 9300 total iterations (24.591%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.809e-14  2.340e-02  y₀ = inv(x₀) + 1.4901e-08
# 7           3.210e-14  5.704e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 9           3.082e-14  2.033e-02  y₀ = inv((inv(x₁ + -0.061777) * -5.707e-11) + x₀)
# 10          2.541e-14  1.932e-01  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# 12          2.336e-14  4.196e-02  y₀ = inv(inv(inv(x₀) + (x₁ * -0.24803))) + (x₁ * 0.24803)
# 17          2.201e-14  1.193e-02  y₀ = inv(((-2.1451e-10 * x₀) * inv((x₄ * -0.12797) + ((x₀...
#                                         * x₄) * x₄))) + x₀)
# 21          2.172e-14  3.249e-03  y₀ = inv(x₀ + inv((x₀ + -0.069029) * inv((x₀ + ((x₀ * inv...
#                                        (x₁ + x₂)) * -0.069029)) * -2.2226e-09)))
# 23          1.320e-14  2.492e-01  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + ((((x₀ * x₂) + ...
#                                        0.33284) * inv(x₂)) * -0.069029)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 12          7.538e-15  3.127e-03  y₁ = ((x₄ * ((-1.3176 + x₀) * 3.3836e-09)) + 1) * inv(x₁)
# 14          7.041e-15  3.413e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 15          6.517e-15  7.734e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 21          6.499e-15  4.549e-04  y₁ = (((inv(x₁) * 1.9475e-10) + ((x₄ * ((x₂ * -1.4139e-09...
#                                        ) * (2.2551 + x₁))) + -2.1865e-08)) + 1) * inv(x₁)
# 23          5.442e-15  8.874e-02  y₁ = ((1 + (inv(x₁) * 1.9475e-10)) * inv(x₁)) + ((inv(x₂ ...
#                                        + inv(x₄)) * inv(inv(x₃) * -0.618)) * -1.4139e-09)
# 25          5.336e-15  9.889e-03  y₁ = inv(x₁) * (((inv(x₁) * 1.9475e-10) + ((x₄ * (inv((x₄...
#                                         + x₄) + -0.4078) * -1.4139e-09)) * (inv(x₄) * 1.8978))) ...
#                                        + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.162e-15  1.793e-02  y₂ = (1 + ((inv(x₀ * -2.031) + (10.239 + (x₄ + x₀))) * 3....
#                                        7253e-09)) * inv(x₂)
# 19          2.649e-15  8.850e-02  y₂ = inv(x₂) * (1 + (((((x₃ * x₃) + inv(-2.1313 * x₀)) + ...
#                                        x₄) + 9.4079) * 3.7253e-09))
# 21          2.423e-15  4.469e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 25          2.285e-15  1.463e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 28          2.263e-15  3.255e-03  y₂ = inv(x₂) * (((((inv((x₀ + -1.0101) * (x₁ + -0.75113))...
#                                         + x₄) + inv(x₀ * -2.031)) + ((x₂ * x₂) + 9.8173)) * 3.72...
#                                        53e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.110e+05
# Progress: 2781 / 9300 total iterations (29.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.809e-14  2.340e-02  y₀ = inv(x₀) + 1.4901e-08
# 7           3.210e-14  5.704e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           3.063e-14  4.688e-02  y₀ = inv(inv(inv(x₀) + 0.4455)) + -0.4455
# 10          2.541e-14  9.347e-02  y₀ = (((inv(x₀) * -0.76664) + 0.25985) * -1.3044) + 0.338...
#                                        94
# 12          2.336e-14  4.196e-02  y₀ = inv(inv(inv(x₀) + (x₁ * -0.24803))) + (x₁ * 0.24803)
# 14          2.289e-14  1.018e-02  y₀ = (x₁ * 0.24803) + (inv(inv((-0.24803 * x₁) + inv(x₀))...
#                                        ) + 2.5745e-08)
# 15          2.201e-14  3.927e-02  y₀ = inv((-2.1451e-10 * (x₀ * inv(x₄ * (-0.12797 + (x₀ * ...
#                                        x₄))))) + x₀)
# 16          2.187e-14  6.478e-03  y₀ = inv(((x₃ + ((x₁ * inv(x₃)) + 0.49121)) * (-7.4682e-1...
#                                        1 * inv(x₂))) + x₀)
# 18          2.172e-14  3.260e-03  y₀ = inv((((x₃ + (((x₁ * inv(x₃)) + x₀) + 0.49121)) * -7....
#                                        4682e-11) * inv(x₂)) + x₀)
# 19          1.320e-14  4.984e-01  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + (inv(x₂) * (-0....
#                                        069029 * 0.33284))) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 12          7.538e-15  3.127e-03  y₁ = ((x₄ * ((-1.3176 + x₀) * 3.3836e-09)) + 1) * inv(x₁)
# 14          7.041e-15  3.413e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 15          6.517e-15  7.734e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 18          5.336e-15  6.666e-02  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 28          5.194e-15  2.699e-03  y₁ = inv(x₁) * (((1.9475e-10 * inv(x₁)) + 1) + (x₄ * ((in...
#                                        v(0.71395 * (x₄ * (x₁ + -0.20275))) + (x₄ + -1.0236)) * (...
#                                        -1.4139e-09 * 0.52693))))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.162e-15  1.793e-02  y₂ = (1 + ((inv(x₀ * -2.031) + (10.239 + (x₄ + x₀))) * 3....
#                                        7253e-09)) * inv(x₂)
# 19          2.649e-15  8.850e-02  y₂ = inv(x₂) * (1 + (((((x₃ * x₃) + inv(-2.1313 * x₀)) + ...
#                                        x₄) + 9.4079) * 3.7253e-09))
# 21          2.423e-15  4.469e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 25          2.285e-15  1.463e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 27          2.143e-15  3.211e-02  y₂ = (((((x₄ + x₂) * -0.36068) + (x₃ + ((x₃ * x₃) + (x₄ +...
#                                         (9.4079 + inv(x₀ * -2.1313)))))) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.070e+05
# Progress: 3240 / 9300 total iterations (34.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.210e-14  1.987e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           1.918e-14  5.151e-01  y₀ = inv(inv(inv(x₀) + 0.42976)) + -0.42976
# 17          1.320e-14  4.152e-02  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + (inv(x₂) * -0.0...
#                                        22976)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 10          7.476e-15  1.766e-02  y₁ = inv(x₁) * (((x₀ * -5.2717e-09) * x₂) + 1)
# 12          7.334e-15  9.595e-03  y₁ = (((x₀ * (x₂ + -0.085104)) * -5.2717e-09) + 1) * inv(...
#                                        x₁)
# 14          7.041e-15  2.039e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 15          6.517e-15  7.734e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 18          5.336e-15  6.666e-02  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 26          5.194e-15  3.374e-03  y₁ = inv(x₁) * (((1.9475e-10 * inv(x₁)) + 1) + ((inv(0.71...
#                                        395 * (x₄ * (x₁ + -0.20275))) + x₄) * ((-1.4139e-09 * 0.5...
#                                        2693) * x₄)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.135e-15  2.216e-02  y₂ = inv(x₂) * (((((inv(x₀ * -2.1313) + x₄) * 0.56643) + ...
#                                        9.1681) * 3.7253e-09) + 1)
# 19          2.602e-15  9.315e-02  y₂ = inv(x₂) * ((((x₄ + 10.239) + ((x₃ * 0.24103) + inv(x...
#                                        ₀ * -2.031))) * 3.7253e-09) + 1)
# 21          2.423e-15  3.581e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 25          2.285e-15  1.463e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 27          2.143e-15  3.211e-02  y₂ = (((((x₄ + x₂) * -0.36068) + (x₃ + ((x₃ * x₃) + (x₄ +...
#                                         (9.4079 + inv(x₀ * -2.1313)))))) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.060e+05
# Progress: 3716 / 9300 total iterations (39.957%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.210e-14  1.987e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           1.918e-14  5.151e-01  y₀ = inv(inv(inv(x₀) + 0.42976)) + -0.42976
# 17          1.320e-14  4.152e-02  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + (inv(x₂) * -0.0...
#                                        22976)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 10          7.476e-15  1.766e-02  y₁ = inv(x₁) * (((x₀ * -5.2717e-09) * x₂) + 1)
# 12          7.334e-15  9.595e-03  y₁ = (((x₀ * (x₂ + -0.085104)) * -5.2717e-09) + 1) * inv(...
#                                        x₁)
# 14          7.041e-15  2.039e-02  y₁ = (inv(x₁) * (1 + (inv(x₁) * 1.7722e-10))) + (inv(x₂) ...
#                                        * -1.6734e-10)
# 15          6.517e-15  7.734e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 18          5.336e-15  6.666e-02  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 24          5.194e-15  4.499e-03  y₁ = ((inv(x₁) * 1.9475e-10) + ((((inv((x₄ * (x₁ + -0.202...
#                                        75)) * 0.71209) + x₄) * x₄) * -7.4504e-10) + 1)) * inv(x₁...
#                                        )
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.135e-15  2.216e-02  y₂ = inv(x₂) * (((((inv(x₀ * -2.1313) + x₄) * 0.56643) + ...
#                                        9.1681) * 3.7253e-09) + 1)
# 19          2.602e-15  9.315e-02  y₂ = inv(x₂) * ((((x₄ + 10.239) + ((x₃ * 0.24103) + inv(x...
#                                        ₀ * -2.031))) * 3.7253e-09) + 1)
# 21          2.423e-15  3.581e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 25          2.285e-15  1.463e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 27          2.143e-15  3.211e-02  y₂ = (((((x₄ + x₂) * -0.36068) + (x₃ + ((x₃ * x₃) + (x₄ +...
#                                         (9.4079 + inv(x₀ * -2.1313)))))) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.040e+05
# Progress: 4180 / 9300 total iterations (44.946%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.210e-14  1.987e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           1.918e-14  5.151e-01  y₀ = inv(inv(inv(x₀) + 0.42976)) + -0.42976
# 17          1.320e-14  4.152e-02  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + (inv(x₂) * -0.0...
#                                        22976)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 10          7.476e-15  1.766e-02  y₁ = inv(x₁) * (((x₀ * -5.2717e-09) * x₂) + 1)
# 12          7.334e-15  9.595e-03  y₁ = (((x₀ * (x₂ + -0.085104)) * -5.2717e-09) + 1) * inv(...
#                                        x₁)
# 14          6.908e-15  2.994e-02  y₁ = inv(x₁) * ((((x₂ * (x₀ + -1.0853)) + x₄) * -4.9072e-...
#                                        09) + 1)
# 15          6.517e-15  5.824e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 18          5.336e-15  6.666e-02  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 19          4.767e-15  1.126e-01  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.135e-15  2.216e-02  y₂ = inv(x₂) * (((((inv(x₀ * -2.1313) + x₄) * 0.56643) + ...
#                                        9.1681) * 3.7253e-09) + 1)
# 19          2.602e-15  9.315e-02  y₂ = inv(x₂) * ((((x₄ + 10.239) + ((x₃ * 0.24103) + inv(x...
#                                        ₀ * -2.031))) * 3.7253e-09) + 1)
# 21          2.423e-15  3.581e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 23          2.414e-15  1.837e-03  y₂ = ((((((x₂ + (x₄ * 0.88358)) * (x₂ + 0.83082)) + inv(x...
#                                        ₀ * -2.031)) + 9.4079) * 3.7253e-09) + 1) * inv(x₂)
# 25          2.285e-15  2.742e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 27          2.143e-15  3.211e-02  y₂ = (((((x₄ + x₂) * -0.36068) + (x₃ + ((x₃ * x₃) + (x₄ +...
#                                         (9.4079 + inv(x₀ * -2.1313)))))) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.030e+05
# Progress: 4670 / 9300 total iterations (50.215%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.210e-14  1.987e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           1.622e-14  6.824e-01  y₀ = -0.40321 + inv(inv(inv(x₀) + 0.40321))
# 17          1.320e-14  2.292e-02  y₀ = inv(inv((x₀ + -0.069029) * inv((x₀ + (inv(x₂) * -0.0...
#                                        22976)) * -2.2226e-09)) + x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 10          7.334e-15  3.685e-02  y₁ = inv(x₁) * (((x₂ * x₀) * -4.9072e-09) + 1)
# 12          7.228e-15  7.319e-03  y₁ = (((x₂ * -5.495e-09) * (x₀ + -0.37517)) + 1) * inv(x₁...
#                                        )
# 14          6.908e-15  2.262e-02  y₁ = inv(x₁) * ((((x₂ * (x₀ + -1.0853)) + x₄) * -4.9072e-...
#                                        09) + 1)
# 15          6.517e-15  5.824e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 16          5.345e-15  1.983e-01  y₁ = (((inv(x₀ + -0.7638) * -3.1885e-09) + 1) + (inv(x₁) ...
#                                        * 1.9475e-10)) * inv(x₁)
# 18          5.336e-15  8.316e-04  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 19          4.767e-15  1.126e-01  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.277e-15  3.512e-01  y₂ = (((x₄ + (inv(x₀ * -2.031) + 10.14)) * 3.7253e-09) + ...
#                                        1) * inv(x₂)
# 17          3.135e-15  2.216e-02  y₂ = inv(x₂) * (((((inv(x₀ * -2.1313) + x₄) * 0.56643) + ...
#                                        9.1681) * 3.7253e-09) + 1)
# 19          2.558e-15  1.018e-01  y₂ = (((inv(x₀ * -2.031) + ((x₄ * (x₂ + 1.2427)) + 10.239...
#                                        )) * 3.6469e-09) + 1) * inv(x₂)
# 21          2.423e-15  2.720e-02  y₂ = (((((x₄ + x₂) * (x₂ + 0.83082)) + (inv(x₀ * -2.031) ...
#                                        + 9.4079)) * 3.7253e-09) + 1) * inv(x₂)
# 23          2.356e-15  1.394e-02  y₂ = inv(x₂) * (((((((x₃ * x₃) + 9.4079) + x₃) + x₄) + in...
#                                        v((x₀ * -1.274) + 0.056704)) * 3.7253e-09) + 1)
# 25          2.285e-15  1.531e-02  y₂ = inv(x₂) * (((((x₄ * -0.36068) + (x₃ * x₃)) + (((x₃ +...
#                                         x₄) + 9.4079) + inv(x₀ * -2.1313))) * 3.7253e-09) + 1)
# 27          2.143e-15  3.211e-02  y₂ = (((((x₄ + x₂) * -0.36068) + (x₃ + ((x₃ * x₃) + (x₄ +...
#                                         (9.4079 + inv(x₀ * -2.1313)))))) * 3.7253e-09) + 1) * in...
#                                        v(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.020e+05
# Progress: 5127 / 9300 total iterations (55.129%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.210e-14  1.987e-02  y₀ = inv(x₀) * (x₂ * inv(x₂))
# 8           6.239e-15  1.638e+00  y₀ = inv(inv(inv(x₀) + 0.59709)) + -0.59709
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           7.609e-15  8.820e-02  y₁ = (1 + (inv(x₁) * 1.7722e-10)) * inv(x₁)
# 10          7.334e-15  3.685e-02  y₁ = inv(x₁) * (((x₂ * x₀) * -4.9072e-09) + 1)
# 12          7.228e-15  7.319e-03  y₁ = (((x₂ * -5.495e-09) * (x₀ + -0.37517)) + 1) * inv(x₁...
#                                        )
# 14          6.908e-15  2.262e-02  y₁ = inv(x₁) * ((((x₂ * (x₀ + -1.0853)) + x₄) * -4.9072e-...
#                                        09) + 1)
# 15          6.517e-15  5.824e-02  y₁ = ((inv(x₁) * 1.9475e-10) + ((x₄ * (x₂ * -3.1885e-09))...
#                                         + 1)) * inv(x₁)
# 16          5.345e-15  1.983e-01  y₁ = (((inv(x₀ + -0.7638) * -3.1885e-09) + 1) + (inv(x₁) ...
#                                        * 1.9475e-10)) * inv(x₁)
# 18          5.336e-15  8.316e-04  y₁ = inv(x₁) * (((inv(-0.41676 + (x₁ + x₁)) * -3.1885e-09...
#                                        ) + 1) + (1.9475e-10 * inv(x₁)))
# 19          4.767e-15  1.126e-01  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# ...
#                                        .55594) + 9.1681) + inv(x₀ * -2.1313)) * 3.7253e-09) + 1)
# 25          2.103e-15  4.298e-02  y₂ = inv(x₂) * (((x₄ + (inv(x₀ * -2.7792) + (9.4079 + (((...
#                                        -0.44511 * x₄) * x₃) + (x₂ * x₂))))) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.650e+04
# Progress: 8372 / 9300 total iterations (90.022%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.139e-14  2.733e-02  y₀ = inv(x₀ + (inv(x₁) * 2.5285e-10))
# 8           4.277e-15  1.993e+00  y₀ = inv(inv(0.16327 + inv(x₀))) + -0.16327
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           6.211e-15  2.913e-01  y₁ = (inv(x₁) + (inv(x₁) * -0.27715)) * 1.3834
# 14          5.336e-15  3.037e-02  y₁ = inv(x₁) * ((1.9475e-10 * (inv(x₁) + inv(x₁ + -0.1883...
#                                        3))) + 1)
# 19          4.767e-15  2.253e-02  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# 25          4.625e-15  5.044e-03  y₁ = inv(x₁) * (((((inv(inv(x₃) + 3.6095) + x₀) + x₀) + 0...
#                                        .86985) * (inv((x₁ + -0.41676) + x₁) * -3.6419e-09)) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.126e-15  3.983e-01  y₂ = ((((x₄ + inv(x₀ * -2.2938)) + 10.14) * 3.7253e-09) +...
#                                         1) * inv(x₂)
# 17          2.971e-15  2.550e-02  y₂ = ((((x₄ + inv(x₀ * (-1.2976 + x₀))) + 10.14) * 3.7253...
#                                        e-09) + 1) * inv(x₂)
# 19          2.558e-15  7.484e-02  y₂ = (((inv(x₀ * -2.031) + ((x₄ * (x₂ + 1.2427)) + 10.239...
#                                        )) * 3.6469e-09) + 1) * inv(x₂)
# 21          2.414e-15  2.904e-02  y₂ = inv(x₂) * ((((x₄ + (inv(x₀ * -2.7792) + 9.4079)) + (...
#                                        x₂ * (x₂ + x₄))) * 3.7253e-09) + 1)
# 23          2.292e-15  2.596e-02  y₂ = inv(x₂) * ((((((((x₃ + 0.69599) * 0.69599) + x₄) * 0...
#                                        .55594) + 9.1681) + inv(x₀ * -2.1313)) * 3.7253e-09) + 1)
# 25          2.103e-15  4.298e-02  y₂ = inv(x₂) * (((x₄ + (inv(x₀ * -2.7792) + (9.4079 + (((...
#                                        -0.44511 * x₄) * x₃) + (x₂ * x₂))))) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.000e+05
# Progress: 8884 / 9300 total iterations (95.527%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.139e-14  2.733e-02  y₀ = inv(x₀ + (inv(x₁) * 2.5285e-10))
# 8           4.277e-15  1.993e+00  y₀ = inv(inv(0.16327 + inv(x₀))) + -0.16327
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           6.211e-15  2.913e-01  y₁ = (inv(x₁) + (inv(x₁) * -0.27715)) * 1.3834
# 14          5.336e-15  3.037e-02  y₁ = inv(x₁) * ((1.9475e-10 * (inv(x₁) + inv(x₁ + -0.1883...
#                                        3))) + 1)
# 19          4.767e-15  2.253e-02  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# 25          4.625e-15  5.044e-03  y₁ = inv(x₁) * (((((inv(inv(x₃) + 3.6095) + x₀) + x₀) + 0...
#                                        .86985) * (inv((x₁ + -0.41676) + x₁) * -3.6419e-09)) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 10          5.542e-15  3.379e-02  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.126e-15  3.983e-01  y₂ = ((((x₄ + inv(x₀ * -2.2938)) + 10.14) * 3.7253e-09) +...
#                                         1) * inv(x₂)
# 17          2.971e-15  2.550e-02  y₂ = ((((x₄ + inv(x₀ * (-1.2976 + x₀))) + 10.14) * 3.7253...
#                                        e-09) + 1) * inv(x₂)
# 18          2.887e-15  2.881e-02  y₂ = ((3.7253e-09 * (x₄ + (inv(x₀ * (x₀ + inv(-0.58007)))...
#                                         + 10.14))) + 1) * inv(x₂)
# 19          2.558e-15  1.209e-01  y₂ = (((inv(x₀ * -2.031) + ((x₄ * (x₂ + 1.2427)) + 10.239...
#                                        )) * 3.6469e-09) + 1) * inv(x₂)
# 21          2.414e-15  2.904e-02  y₂ = inv(x₂) * ((((x₄ + (inv(x₀ * -2.7792) + 9.4079)) + (...
#                                        x₂ * (x₂ + x₄))) * 3.7253e-09) + 1)
# 23          2.292e-15  2.596e-02  y₂ = inv(x₂) * ((((((((x₃ + 0.69599) * 0.69599) + x₄) * 0...
#                                        .55594) + 9.1681) + inv(x₀ * -2.1313)) * 3.7253e-09) + 1)
# 25          2.103e-15  4.298e-02  y₂ = inv(x₂) * (((x₄ + (inv(x₀ * -2.7792) + (9.4079 + (((...
#                                        -0.44511 * x₄) * x₃) + (x₂ * x₂))))) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  0.000e+00  y₀ = -1.3215
# 2           3.991e-14  3.476e+01  y₀ = inv(x₀)
# 4           3.407e-14  7.916e-02  y₀ = inv(x₀) * 1
# 7           3.139e-14  2.733e-02  y₀ = inv(x₀ + (inv(x₁) * 2.5285e-10))
# 8           4.277e-15  1.993e+00  y₀ = inv(inv(0.16327 + inv(x₀))) + -0.16327
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.279e+02  0.000e+00  y₁ = x₀
# 2           2.336e-12  3.322e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.907e-06  y₁ = (x₂ * -5.0541e-09) + inv(x₁)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0894e-08)
# 8           8.311e-15  4.930e-01  y₁ = inv(x₁) * ((x₂ * 1.5162e-08) + 1)
# 9           6.211e-15  2.913e-01  y₁ = (inv(x₁) + (inv(x₁) * -0.27715)) * 1.3834
# 14          5.336e-15  3.037e-02  y₁ = inv(x₁) * ((1.9475e-10 * (inv(x₁) + inv(x₁ + -0.1883...
#                                        3))) + 1)
# 19          4.767e-15  2.253e-02  y₁ = (((inv((x₁ + x₁) + -0.41676) * -3.1885e-09) * ((x₀ +...
#                                         1) + x₀)) + 1) * inv(x₁)
# 25          4.625e-15  5.044e-03  y₁ = inv(x₁) * (((((inv(inv(x₃) + 3.6095) + x₀) + x₀) + 0...
#                                        .86985) * (inv((x₁ + -0.41676) + x₁) * -3.6419e-09)) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  0.000e+00  y₂ = 13.141
# 2           1.490e-10  3.248e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.998e+00  y₂ = inv(x₂ + 3.0922e-11)
# 8           5.578e-15  4.909e-02  y₂ = inv(x₂) * ((x₄ * 1.3616e-08) + 1)
# 10          5.542e-15  3.195e-03  y₂ = inv(x₂) * (((x₄ + 10.215) * 3.7253e-09) + 1)
# 12          5.118e-15  3.980e-02  y₂ = inv(x₂) * ((((x₀ + x₄) + 12.357) * 3.7253e-09) + 1)
# 14          4.656e-15  4.729e-02  y₂ = inv(x₂) * (((x₄ + ((x₄ + x₀) + 15.61)) * 3.7253e-09)...
#                                         + 1)
# 15          3.126e-15  3.983e-01  y₂ = ((((x₄ + inv(x₀ * -2.2938)) + 10.14) * 3.7253e-09) +...
#                                         1) * inv(x₂)
# 17          2.971e-15  2.550e-02  y₂ = ((((x₄ + inv(x₀ * (-1.2976 + x₀))) + 10.14) * 3.7253...
#                                        e-09) + 1) * inv(x₂)
# 18          2.887e-15  2.881e-02  y₂ = ((3.7253e-09 * (x₄ + (inv(x₀ * (x₀ + inv(-0.58007)))...
#                                         + 10.14))) + 1) * inv(x₂)
# 19          2.558e-15  1.209e-01  y₂ = (((inv(x₀ * -2.031) + ((x₄ * (x₂ + 1.2427)) + 10.239...
#                                        )) * 3.6469e-09) + 1) * inv(x₂)
# 21          2.414e-15  2.904e-02  y₂ = inv(x₂) * ((((x₄ + (inv(x₀ * -2.7792) + 9.4079)) + (...
#                                        x₂ * (x₂ + x₄))) * 3.7253e-09) + 1)
# 23          2.292e-15  2.596e-02  y₂ = inv(x₂) * ((((((((x₃ + 0.69599) * 0.69599) + x₄) * 0...
#                                        .55594) + 9.1681) + inv(x₀ * -2.1313)) * 3.7253e-09) + 1)
# 25          2.103e-15  4.298e-02  y₂ = inv(x₂) * (((x₄ + (inv(x₀ * -2.7792) + (9.4079 + (((...
#                                        -0.44511 * x₄) * x₃) + (x₂ * x₂))))) * 3.7253e-09) + 1)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs/20260227_201519_X9fhD3/hall_of_fame_output1.csv
#   - outputs/20260227_201519_X9fhD3/hall_of_fame_output2.csv
# [ Info: Final populations:
# [ Info: Output 1:
# [ Info: Output 2:
# [ Info: Output 3:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# [
# 	   pick      score                                      equation  \
# 	0         0.000000                                    -1.3215431
# 	1        34.757929                                       inv(x0)
# 	2         0.079156                                 inv(x0) * 1.0
# 	3         0.027333           inv(x0 + (inv(x1) * 2.5284677e-10))
# 	4  >>>>   1.993279  inv(inv(0.16326858 + inv(x0))) + -0.16326857
#
# 	           loss  complexity
# 	0  4.969471e+01           1
# 	1  3.991474e-14           2
# 	2  3.407053e-14           4
# 	3  3.138822e-14           7
# 	4  4.276579e-15           8
# ], [
# 	   pick      score                                           equation  \
# 	0         0.000000                                                 x0
# 	1        33.224942                                            inv(x1)
# 	2         0.000002                      (x2 * -5.054069e-9) + inv(x1)
# 	3         5.145575                inv(x1) + (inv(x1) * -4.0893937e-8)
# 	4         0.492981              inv(x1) * ((x2 * 1.5161673e-8) + 1.0)
# 	5  >>>>   0.291340    (inv(x1) + (inv(x1) * -0.27715123)) * 1.3834152
# 	6         0.030366  inv(x1) * ((1.9474822e-10 * (inv(x1) + inv(x1 ...
# 	7         0.022529  (((inv((x1 + x1) + -0.41676277) * -3.1885417e-...
# 	8         0.005044  inv(x1) * (((((inv(inv(x3) + 3.6094613) + x0) ...
#
# 	           loss  complexity
# 	0  6.278647e+02           1
# 	1  2.335916e-12           2
# 	2  2.335898e-12           6
# 	3  1.360689e-14           7
# 	4  8.311130e-15           8
# 	5  6.210587e-15           9
# 	6  5.335732e-15          14
# 	7  4.767297e-15          19
# 	8  4.625189e-15          25
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          13.141065
# 	1         32.484459                                            inv(x2)
# 	2          4.998341                             inv(x2 + 3.092216e-11)
# 	3          0.049089              inv(x2) * ((x4 * 1.3616303e-8) + 1.0)
# 	4          0.003195  inv(x2) * (((x4 + 10.215377) * 3.7252903e-9) +...
# 	5          0.039804  inv(x2) * ((((x0 + x4) + 12.357015) * 3.725290...
# 	6          0.047286  inv(x2) * (((x4 + ((x4 + x0) + 15.609678)) * 3...
# 	7   >>>>   0.398337  ((((x4 + inv(x0 * -2.293807)) + 10.139861) * 3...
# 	8          0.025497  ((((x4 + inv(x0 * (-1.2976108 + x0))) + 10.139...
# 	9          0.028812  ((3.7252903e-9 * (x4 + (inv(x0 * (x0 + inv(-0....
# 	10         0.120865  (((inv(x0 * -2.0310187) + ((x4 * (x2 + 1.24267...
# 	11         0.029039  inv(x2) * ((((x4 + (inv(x0 * -2.7791712) + 9.4...
# 	12         0.025961  inv(x2) * ((((((((x3 + 0.69599396) * 0.6959939...
# 	13         0.042977  inv(x2) * (((x4 + (inv(x0 * -2.7791712) + (9.4...
#
# 	            loss  complexity
# 	0   1.910123e+04           1
# 	1   1.490184e-10           2
# 	2   6.787903e-15           4
# 	3   5.577761e-15           8
# 	4   5.542233e-15          10
# 	5   5.118128e-15          12
# 	6   4.656275e-15          14
# 	7   3.126388e-15          15
# 	8   2.970957e-15          17
# 	9   2.886580e-15          18
# 	10  2.557954e-15          19
# 	11  2.413625e-15          21
# 	12  2.291500e-15          23
# 	13  2.102762e-15          25
# ]]
#   - outputs/20260227_201519_X9fhD3/hall_of_fame_output3.csv

# %%
model
# Out:
# PySRRegressor.equations_ = [
# [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -1.3211881
# 	1         34.757929                                            inv(x0)
# 	2          0.000056                      (x2 * 5.1984093e-9) + inv(x0)
# 	3          0.240090                inv((1.8871506e-10 * inv(x1)) + x0)
# 	4          0.009138          inv(x0 + (inv(x3 * x3) * -1.4312279e-10))
# 	5          0.214740  inv(((inv(x3 * x3) + inv(x2)) * -1.5457022e-10...
# 	6          0.151410  inv(x0 + ((inv(x2) + (inv(x3) * inv(x3))) * -1...
# 	7          0.032153  inv((-1.1047916e-10 * ((inv(0.012490549 + x2) ...
# 	8          0.288855  inv(x0 + ((((inv(x3) + inv(x4 * -1.832546)) * ...
# 	9   >>>>   0.136636  inv(((inv(x1 * -0.4922888) + (((x1 + inv(x4 * ...
# 	10         0.074556  inv((((inv(x1 + x0) + 0.95332456) + ((x1 + (in...
# 	11         0.005051  inv(((((x1 + (x0 + (inv(x4 * (x0 + -1.7996889)...
#
# 	            loss  complexity
# 	0   4.969471e+01           1
# 	1   3.991474e-14           2
# 	2   3.990586e-14           6
# 	3   3.138822e-14           7
# 	4   3.081979e-14           9
# 	5   1.618261e-14          12
# 	6   1.390887e-14          13
# 	7   1.262990e-14          16
# 	8   7.087664e-15          18
# 	9   4.103384e-15          22
# 	10  3.534950e-15          24
# 	11  3.499423e-15          26
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                        -0.22260998
# 	1         33.237197                                            inv(x1)
# 	2          0.000002                     (x2 * -5.8327507e-9) + inv(x1)
# 	3          5.145575                (inv(x1) * -4.0935312e-8) + inv(x1)
# 	4          0.290592            inv(x1) + (2.868932e-10 * inv(x1 * x1))
# 	5          0.005011  (inv(x1 * (x3 + (0.53711706 * x1))) * -6.23986...
# 	6   >>>>   0.333262  (inv(x1 * ((x1 * inv(x4)) + x3)) * -6.2398695e...
# 	7          0.001663  inv(x1) + (inv((((x3 + 6.958106) * x1) + x3) *...
# 	8          0.026995  (inv(x1 * (((x1 + inv(x4)) * x1) + x3)) * -5.2...
# 	9          0.042826  (inv(x1 * ((((x3 * x0) + inv(x4)) * x1) + x3))...
# 	10         0.007566  inv(x1) + (inv(x1 * ((((inv(x4) + (x0 * -1.044...
# 	11         0.000384  (inv(x1 * (x3 + (((inv(x4) + (x3 * x0)) + inv(...
# 	12         0.094781  (inv(x1 * (x3 + (((inv(x4) + (x3 * x0)) + inv(...
#
# 	            loss  complexity
# 	0   6.356064e+02           1
# 	1   2.335916e-12           2
# 	2   2.335898e-12           6
# 	3   1.360689e-14           7
# 	4   7.609469e-15           9
# 	5   7.458478e-15          13
# 	6   5.344614e-15          14
# 	7   5.335732e-15          15
# 	8   5.193623e-15          16
# 	9   4.767297e-15          18
# 	10  4.625189e-15          22
# 	11  4.616307e-15          27
# 	12  4.198863e-15          28
# ], [
# 	   pick      score                                           equation  \
# 	0         0.000000                                          13.149121
# 	1        32.484459                                            inv(x2)
# 	2         4.998341                              inv(x2 + 3.79011e-11)
# 	3         0.006652         inv((x2 + 3.5566657e-11) * (inv(x2) * x2))
# 	4         0.016366        inv(x2 * inv(x2)) * inv(x2 + 3.5566657e-11)
# 	5         0.164294  (inv(x2 * ((-0.29179946 + x4) * x2)) * 1.42798...
# 	6  >>>>   0.040426  (inv((x2 * (x2 + (x4 * -0.45794418))) * (x2 + ...
#
# 	           loss  complexity
# 	0  1.910123e+04           1
# 	1  1.490184e-10           2
# 	2  6.787903e-15           4
# 	3  6.565859e-15           9
# 	4  6.459278e-15          10
# 	5  3.945733e-15          13
# 	6  2.240430e-15          27
# ]]

# %% [markdown]
# # Julia packages and types

# %% [markdown]
# PySR uses [SymbolicRegression.jl](https://github.com/MilesCranmer/SymbolicRegression.jl)
# as its search backend. This is a pure Julia package, and so can interface easily with any other
# Julia package.
# For some tasks, it may be necessary to load such a package.
#
# For example, let's say we wish to discovery the following relationship:
#
# $$ y = p_{3x + 1} - 5, $$
#
# where $p_i$ is the $i$th prime number, and $x$ is the input feature.
#
# Let's see if we can discover this using
# the [Primes.jl](https://github.com/JuliaMath/Primes.jl) package.

# %% [markdown]
# `jl` stores the Julia runtime.
#
# Now, let's run some Julia code to add the Primes.jl
# package to the PySR environment:

# %%
from pysr import jl

jl.seval(
    """
import Pkg
Pkg.add("Primes")
"""
)
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed Primes ─────────── v0.5.7
#    Installed IntegerMathUtils ─ v0.1.3
#     Updating `~/.conda/envs/pysr/julia_env/Project.toml`
#   [27ebfcd6] + Primes v0.5.7
#     Updating `~/.conda/envs/pysr/julia_env/Manifest.toml`
#   [18e54dd8] + IntegerMathUtils v0.1.3
#   [27ebfcd6] + Primes v0.5.7
# Precompiling packages...
#     677.6 ms  ✓ IntegerMathUtils
#     961.4 ms  ✓ Primes
#   2 dependencies successfully precompiled in 3 seconds. 155 already precompiled.

# %% [markdown]
# This imports the Julia package manager, and uses it to install
# `Primes.jl`. Now let's import `Primes.jl`:

# %%
jl.seval("using Primes: prime")

# %% [markdown]
# Note that PySR should automatically load the `juliacall.ipython` extension for you,
# which means that you can also execute Julia code in the notebook using the `%%julia` magic:

# %%
# %julia using Primes: prime

# %% [markdown]
# Now, we define a custom operator:

# %%
jl.seval(
    """
function p(i::T) where T
    if 0.5 < i < 1000
        return T(prime(round(Int, i)))
    else
        return T(NaN)
    end
end
"""
)
# Out:
# p (generic function with 1 method)

# %% [markdown]
# Or, equivalently:

# %%
# %%julia
# function p(i::T) where T
#     if 0.5 < i < 1000
#         return T(prime(round(Int, i)))
#     else
#         return T(NaN)
#     end
# end
# Out:
# p (generic function with 1 method)

# %% [markdown]
# We have created a function `p`, which takes a number `i` of type `T` (e.g., `T=Float64`).
# `p` first checks whether the input is between 0.5 and 1000.
# If out-of-bounds, it returns `NaN`.
# If in-bounds, it rounds it to the nearest integer, computes the corresponding prime number, and then
# converts it to the same type as input.
#
# The equivalent function in Python would be:
#
# ```python
# import sympy
#
# def p(i):
#     if 0.5 < i < 1000:
#         return float(sympy.prime(int(round(i))))
#     else:
#         return float("nan")
# ```
#
# (However, note that this version assumes 64-bit float input, rather than any input type `T`)
#
# Next, let's generate a list of primes for our test dataset.
# Since we are using juliacall, we can just call `p` directly to do this:

# %%
primes = {i: jl.p(i * 1.0) for i in range(1, 999)}

# %% [markdown]
# Next, let's use this list of primes to create a dataset of $x, y$ pairs:

# %%
import numpy as np

X = np.random.randint(0, 100, 100)[:, None]
y = [primes[3 * X[i, 0] + 1] - 5 + np.random.randn() * 0.001 for i in range(100)]

# %% [markdown]
# Note that we have also added a tiny bit of noise to the dataset.
#
# Finally, let's create a PySR model, and pass the custom operator. We also need to define the sympy equivalent, which we can leave as a placeholder for now:

# %%
from pysr import PySRRegressor
import sympy


class sympy_p(sympy.Function):
    pass


model = PySRRegressor(
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["p"],
    niterations=20,
    extra_sympy_mappings={"p": sympy_p},
)

# %% [markdown]
# We are all set to go! Let's see if we can find the true relation:

# %%
model.fit(X, y)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.840e+04
# Progress: 80 / 620 total iterations (12.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ - 5.1717) * 20.007
# 8           2.052e+01  1.208e+00  y = p(((x₀ + 0.43577) * 1.9944) + x₀)
# 10          1.104e-06  8.369e+00  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 14          1.104e-06  1.974e-05  y = (p(((x₀ - -0.32229) + (x₀ + 0.39181)) + x₀) - 2.7745) ...
#                                       + -2.2255
# 16          1.099e-06  2.004e-03  y = ((p(((x₀ + 0.3351) + (x₀ + x₀)) + 0.4214) + -0.74359) ...
#                                       - -0.16179) + -4.4182
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.670e+04
# Progress: 164 / 620 total iterations (26.452%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           5.784e+02  2.837e-01  y = p((x₀ + 1.281) * 2.9951)
# 8           2.052e+01  1.669e+00  y = p(((x₀ + 0.43577) * 1.9944) + x₀)
# 10          1.104e-06  8.369e+00  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.087e-06  7.746e-03  y = (p((x₀ + x₀) + (x₀ + 1.3715)) + -4.9998) * 1
# 28          1.082e-06  2.863e-04  y = ((x₀ * -0.50648) + (((x₀ * 0.18832) + (p(((x₀ + 0.7899...
#                                       2) + (x₀ + 0.20812)) + x₀) + -2.4301)) + (x₀ * 1.3182))) +...
#                                        (-2.5696 - x₀)
# 30          1.080e-06  1.077e-03  y = (((x₀ * -1.0059) + ((x₀ * -0.112) + (p((((x₀ + 0.74649...
#                                       ) + (x₀ + 0.081053)) + 0.14069) + x₀) + -2.1836))) + (x₀ *...
#                                        2.1178)) + (-2.816 - x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.570e+04
# Progress: 237 / 620 total iterations (38.226%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           5.784e+02  2.837e-01  y = p((x₀ + 1.281) * 2.9951)
# 8           2.052e+01  1.669e+00  y = p(((x₀ + 0.43577) * 1.9944) + x₀)
# 10          1.104e-06  8.369e+00  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.087e-06  7.746e-03  y = (p((x₀ + x₀) + (x₀ + 1.3715)) + -4.9998) * 1
# 22          1.085e-06  1.381e-04  y = (-2.8114 - x₀) + (((p(((x₀ + x₀) + x₀) + 0.96823) + (x...
#                                       ₀ * -1.0651)) + -2.1884) + (x₀ * 2.0651))
# 24          1.073e-06  5.704e-03  y = (((((x₀ * 0.065272) + p((x₀ + (x₀ + 1.0805)) + x₀)) + ...
#                                       -4.9998) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# 28          1.073e-06  9.561e-05  y = (((x₀ * 0.58798) + (p((x₀ + 0.19242) + ((x₀ + x₀) + 0....
#                                       43274)) + -5.8033)) + (x₀ * -1.5225)) + (x₀ - ((x₀ * 0.065...
#                                       526) + -0.8035))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.640e+04
# Progress: 340 / 620 total iterations (54.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           2.500e+01  3.425e+00  y = p((x₀ * 3) - -1.2183)
# 8           1.697e+01  1.937e-01  y = p((3 * x₀) - -0.54207) - 0.88058
# 10          1.104e-06  8.274e+00  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.087e-06  7.746e-03  y = (p((x₀ + x₀) + (x₀ + 1.3715)) + -4.9998) * 1
# 18          1.079e-06  1.267e-03  y = (x₀ * -1.4354) + (p(x₀ + ((x₀ + 0.6829) + x₀)) + ((x₀ ...
#                                       * 1.4354) + -4.9998))
# 22          1.077e-06  4.727e-04  y = (((p(x₀ + ((x₀ + 0.87486) + x₀)) + -3.672) + ((x₀ * -1...
#                                       .417) + -1.3279)) + (x₀ * 2.417)) - x₀
# 24          1.073e-06  1.648e-03  y = (((((x₀ * 0.065272) + p((x₀ + (x₀ + 1.0805)) + x₀)) + ...
#                                       -4.9998) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# 28          1.073e-06  9.561e-05  y = (((x₀ * 0.58798) + (p((x₀ + 0.19242) + ((x₀ + x₀) + 0....
#                                       43274)) + -5.8033)) + (x₀ * -1.5225)) + (x₀ - ((x₀ * 0.065...
#                                       526) + -0.8035))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.760e+04
# Progress: 426 / 620 total iterations (68.710%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           2.036e+01  3.630e+00  y = p((x₀ - -0.25515) * 2.9959)
# 8           2.365e-06  7.984e+00  y = p((x₀ * 3.0078) - -0.53445) + -5.0011
# 10          1.104e-06  3.810e-01  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.085e-06  8.671e-03  y = (p((x₀ + 0.6914) + (x₀ + x₀)) + -4.9998) * 1
# 18          1.079e-06  9.587e-04  y = (x₀ * -1.4354) + (p(x₀ + ((x₀ + 0.6829) + x₀)) + ((x₀ ...
#                                       * 1.4354) + -4.9998))
# 22          1.077e-06  4.727e-04  y = (((p(x₀ + ((x₀ + 0.87486) + x₀)) + -3.672) + ((x₀ * -1...
#                                       .417) + -1.3279)) + (x₀ * 2.417)) - x₀
# 24          1.073e-06  1.648e-03  y = (((((x₀ * 0.065272) + p((x₀ + (x₀ + 1.0805)) + x₀)) + ...
#                                       -4.9998) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# 28          1.073e-06  9.561e-05  y = (((x₀ * 0.58798) + (p((x₀ + 0.19242) + ((x₀ + x₀) + 0....
#                                       43274)) + -5.8033)) + (x₀ * -1.5225)) + (x₀ - ((x₀ * 0.065...
#                                       526) + -0.8035))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 1.550e+04
# Progress: 512 / 620 total iterations (82.581%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           2.036e+01  3.630e+00  y = p((x₀ - -0.25515) * 2.9959)
# 8           2.365e-06  7.984e+00  y = p((x₀ * 3.0078) - -0.53445) + -5.0011
# 10          1.104e-06  3.810e-01  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.085e-06  8.680e-03  y = (p(x₀ + ((x₀ + x₀) + 0.66767)) + -4.9998) * 1
# 18          1.079e-06  9.554e-04  y = (x₀ * -1.4354) + (p(x₀ + ((x₀ + 0.6829) + x₀)) + ((x₀ ...
#                                       * 1.4354) + -4.9998))
# 22          1.077e-06  4.727e-04  y = (((p(x₀ + ((x₀ + 0.87486) + x₀)) + -3.672) + ((x₀ * -1...
#                                       .417) + -1.3279)) + (x₀ * 2.417)) - x₀
# 24          1.072e-06  2.389e-03  y = ((((p(x₀ + (x₀ + (x₀ + 1.4656))) + -4.9998) + (x₀ * 0....
#                                       065272)) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# Expressions evaluated per second: 1.650e+04
# Progress: 601 / 620 total iterations (96.935%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           2.036e+01  3.630e+00  y = p((x₀ - -0.25515) * 2.9959)
# 8           2.365e-06  7.984e+00  y = p((x₀ * 3.0078) - -0.53445) + -5.0011
# 10          1.104e-06  3.810e-01  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.085e-06  8.680e-03  y = (p(x₀ + ((x₀ + x₀) + 0.66767)) + -4.9998) * 1
# 18          1.079e-06  9.554e-04  y = (x₀ * -1.4354) + (p(x₀ + ((x₀ + 0.6829) + x₀)) + ((x₀ ...
#                                       * 1.4354) + -4.9998))
# 22          1.077e-06  4.727e-04  y = (((p(x₀ + ((x₀ + 0.87486) + x₀)) + -3.672) + ((x₀ * -1...
#                                       .417) + -1.3279)) + (x₀ * 2.417)) - x₀
# 24          1.072e-06  2.389e-03  y = ((((p(x₀ + (x₀ + (x₀ + 1.4656))) + -4.9998) + (x₀ * 0....
#                                       065272)) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  0.000e+00  y = 890.48
# 3           3.145e+03  2.238e+00  y = x₀ * 18.386
# 5           7.682e+02  7.047e-01  y = (x₀ + -5.1718) * 20.007
# 6           2.036e+01  3.630e+00  y = p((x₀ - -0.25515) * 2.9959)
# 8           2.365e-06  7.984e+00  y = p((x₀ * 3.0078) - -0.53445) + -5.0011
# 10          1.104e-06  3.810e-01  y = p((x₀ + (x₀ + 1.3715)) + x₀) + -5
# 12          1.085e-06  8.680e-03  y = (p(x₀ + ((x₀ + x₀) + 0.66767)) + -4.9998) * 1
# 18          1.079e-06  9.554e-04  y = (x₀ * -1.4354) + (p(x₀ + ((x₀ + 0.6829) + x₀)) + ((x₀ ...
#                                       * 1.4354) + -4.9998))
# 22          1.077e-06  4.727e-04  y = (((p(x₀ + ((x₀ + 0.87486) + x₀)) + -3.672) + ((x₀ * -1...
#                                       .417) + -1.3279)) + (x₀ * 2.417)) - x₀
# 24          1.072e-06  2.389e-03  y = ((((p(x₀ + (x₀ + (x₀ + 1.4656))) + -4.9998) + (x₀ * 0....
#                                       065272)) + (x₀ * -0.50686)) + (x₀ * 1.4416)) - x₀
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          890.47595
# 	1        2.249288                                      x0 * 18.38635
# 	2        0.704811                      (x0 + -5.1718016) * 20.006866
# 	3        3.630553                  p((x0 - -0.25514576) * 2.9958687)
# 	4        7.984088        p((x0 * 3.007797) - -0.5344538) + -5.001096
# 	5  >>>>  0.381008       p((x0 + (x0 + 1.3715283)) + x0) + -4.9999614
# 	6        0.008680  (p(x0 + ((x0 + x0) + 0.6676716)) + -4.9997783)...
# 	7        0.000955  (x0 * -1.4354488) + (p(x0 + ((x0 + 0.6828961) ...
# 	8        0.000473  (((p(x0 + ((x0 + 0.8748598) + x0)) + -3.671964...
# 	9        0.002389  ((((p(x0 + (x0 + (x0 + 1.4656179))) + -4.99981...
#
# 	            loss  complexity
# 	0  282735.880000           1
# 	1    3145.388700           3
# 	2     768.216300           5
# 	3      20.358908           6
# 	4       0.000002           8
# 	5       0.000001          10
# 	6       0.000001          12
# 	7       0.000001          18
# 	8       0.000001          22
# 	9       0.000001          24
# ]
#   - outputs/20260227_202943_oo0qb4/hall_of_fame.csv

# %% [markdown]
# if all works out, you should be able to see the true relation (note that the constant offset might not be exactly 1, since it is allowed to round to the nearest integer).
#
# You can get the sympy version of the best equation with:

# %%
model.sympy()
# Out:
# sympy_p(x0 + x0 + x0 + 1.3715283) - 4.9999614

# %% [markdown]
# # High-dimensional input: Neural Nets + Symbolic Regression

# %% [markdown]
# In this example, let's learn a high-dimensional problem. **This will use the method proposed in our NeurIPS paper: https://arxiv.org/abs/2006.11287.**
#
# Let's consider a time series problem:
#
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2*x_{i2})$$
#
# Imagine our time series is 10 timesteps. That is very hard for symbolic regression, even if we impose the inductive bias of $$z=f(\sum g(x_i))$$ - it is the square of the number of possible equations!
#
# But, as in our paper, **we can break this problem down into parts with a neural network. Then approximate the neural network with the symbolic regression!**
#
# Then, instead of, say, $(10^9)^2=10^{18}$ equations, we only have to consider $2\times 10^9$ equations.

# %%
import numpy as np

rstate = np.random.RandomState(0)

N = 100000
Nt = 10
X = 6 * rstate.rand(N, Nt, 5) - 3
y_i = X[..., 0] ** 2 + 6 * np.cos(2 * X[..., 2])
y = np.sum(y_i, axis=1) / y_i.shape[1]
z = y**2
X.shape, y.shape
# Out:
# ((100000, 10, 5), (100000,))

# %% [markdown]
# ## Neural Network definition

# %% [markdown]
# So, as described above, let's first use a neural network with the sum inductive bias to solve this problem.
#
# Essentially, we will learn two neural networks:
# - `f`
# - `g`
#
# each defined as a multi-layer perceptron. We will sum over `g` the same way as in our equation, but we won't define the summed part beforehand.
#
# Then, we will fit `g` and `f` **separately** using symbolic regression.

# %% [markdown]
# > **Warning**
# >
# > We import torch *after* already starting PyJulia. This is required due to interference between their C bindings. If you use torch, and then run PyJulia, you will likely hit a segfault. So keep this in mind for mixed deep learning + PyJulia/PySR workflows.

# %%
# !pip install pytorch_lightning
# Out:
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting torch>=2.1.0 (from pytorch_lightning)
#   Downloading torch-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Collecting tqdm>=4.57.0 (from pytorch_lightning)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>5.4 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from pytorch_lightning) (6.0.3)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting torchmetrics>0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from pytorch_lightning) (26.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from pytorch_lightning) (4.15.0)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohttp-3.13.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: idna>=2.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.11)
# Requirement already satisfied: filelock in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from torch>=2.1.0->pytorch_lightning) (3.24.3)
# Requirement already satisfied: sympy>=1.13.3 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Collecting networkx>=2.5.1 (from torch>=2.1.0->pytorch_lightning)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.6)
# Collecting cuda-bindings==12.9.4 (from torch>=2.1.0->pytorch_lightning)
#   Downloading cuda_bindings-12.9.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.4.5 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch>=2.1.0->pytorch_lightning)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.6.0 (from torch>=2.1.0->pytorch_lightning)
#   Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings==12.9.4->torch>=2.1.0->pytorch_lightning)
#   Downloading cuda_pathfinder-1.4.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: mpmath<1.5,>=1.1.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: numpy>1.20.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from torchmetrics>0.7.0->pytorch_lightning) (2.4.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.3)
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 10.0 MB/s  0:00:00
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading aiohttp-3.13.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.6 MB/s  0:00:00
# Downloading multidict-6.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading yarl-1.22.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (365 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (231 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading propcache-0.4.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (210 kB)
# Downloading torch-2.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (915.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.6/915.6 MB 22.3 MB/s  0:00:19m0:00:0100:01
# Downloading cuda_bindings-12.9.4-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 30.5 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 14.0 MB/s  0:00:36m0:00:0100:02
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 17.6 MB/s  0:00:00eta 0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 18.5 MB/s  0:00:04m0:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 10.6 MB/s  0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 9.9 MB/s  0:00:526m0:00:0100:02
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 19.0 MB/s  0:00:10m0:00:0100:01
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.7 MB/s  0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 19.5 MB/s  0:00:03m0:00:0100:01
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 13.1 MB/s  0:00:20m0:00:0100:01
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 18.4 MB/s  0:00:17m0:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 23.5 MB/s  0:00:11m0:00:0100:01
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 22.7 MB/s  0:00:14m0:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 23.4 MB/s  0:00:01m0:00:0100:01
# Downloading nvidia_nvshmem_cu12-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (139.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 MB 24.6 MB/s  0:00:05m0:00:0100:01
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 MB 32.3 MB/s  0:00:05m0:00:0100:01
# Downloading cuda_pathfinder-1.4.0-py3-none-any.whl (38 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 20.8 MB/s  0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 11.3 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, tqdm, propcache, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, multidict, lightning-utilities, fsspec, frozenlist, cuda-pathfinder, aiohappyeyeballs, yarl, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, cuda-bindings, aiosignal, nvidia-cusolver-cu12, aiohttp, torch, torchmetrics, pytorch_lightning
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32/32 [pytorch_lightning]pytorch_lightning]12]2]2]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 cuda-bindings-12.9.4 cuda-pathfinder-1.4.0 frozenlist-1.8.0 fsspec-2026.2.0 lightning-utilities-0.15.3 multidict-6.7.1 networkx-3.6.1 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.4.5 nvidia-nvtx-cu12-12.8.90 propcache-0.4.1 pytorch_lightning-2.6.1 torch-2.10.0 torchmetrics-1.8.2 tqdm-4.67.3 triton-3.6.0 yarl-1.22.0

# %%
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, TensorDataset
import pytorch_lightning as pl

hidden = 128
total_steps = 50_000


def mlp(size_in, size_out, act=nn.ReLU):
    return nn.Sequential(
        nn.Linear(size_in, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, size_out),
    )


class SumNet(pl.LightningModule):
    def __init__(self):
        super().__init__()

        ########################################################
        # The same inductive bias as above!
        self.g = mlp(5, 1)
        self.f = mlp(1, 1)

    def forward(self, x):
        y_i = self.g(x)[:, :, 0]
        y = torch.sum(y_i, dim=1, keepdim=True) / y_i.shape[1]
        z = self.f(y)
        return z[:, 0]

    ########################################################

    # PyTorch Lightning bookkeeping:
    def training_step(self, batch, batch_idx):
        x, z = batch
        predicted_z = self(x)
        loss = F.mse_loss(predicted_z, z)
        return loss

    def validation_step(self, batch, batch_idx):
        return self.training_step(batch, batch_idx)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.max_lr)
        scheduler = {
            "scheduler": torch.optim.lr_scheduler.OneCycleLR(
                optimizer,
                max_lr=self.max_lr,
                total_steps=self.trainer.estimated_stepping_batches,
                final_div_factor=1e4,
            ),
            "interval": "step",
        }
        return [optimizer], [scheduler]

# %% [markdown]
# ## Data bookkeeping

# %% [markdown]
# Put everything into PyTorch and do a train/test split:

# %%
from multiprocessing import cpu_count

Xt = torch.tensor(X).float()
zt = torch.tensor(z).float()
X_train, X_test, z_train, z_test = train_test_split(Xt, zt, random_state=0)
train_set = TensorDataset(X_train, z_train)
train = DataLoader(
    train_set, batch_size=128, num_workers=cpu_count(), shuffle=True, pin_memory=True
)
test_set = TensorDataset(X_test, z_test)
test = DataLoader(test_set, batch_size=256, num_workers=cpu_count(), pin_memory=True)
# Out:
# /uufs/chpc.utah.edu/common/home/u6007389/.conda/envs/pysr/lib/python3.11/site-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 80 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()

# %% [markdown]
# ## Train the model with PyTorch Lightning on GPUs:

# %% [markdown]
# Start the model:

# %%
pl.seed_everything(0)
model = SumNet()
model.total_steps = total_steps
model.max_lr = 1e-2
# Out:
# Seed set to 0

# %% [markdown]
# PyTorch Lightning trainer object:

# %%
trainer = pl.Trainer(max_steps=total_steps, accelerator="gpu", devices=1)
# Out:
# ---------------------------------------------------------------------------
# MisconfigurationException                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 trainer = pl.Trainer(max_steps=total_steps, accelerator="gpu", devices=1)
#
# File c:\Users\alfon\anaconda3\envs\PySR\Lib\site-packages\pytorch_lightning\utilities\argparse.py:70, in _defaults_from_env_vars.<locals>.insert_env_defaults(self, *args, **kwargs)
#      67 kwargs = dict(list(env_variables.items()) + list(kwargs.items()))
#      69 # all args were already moved to kwargs
# ---> 70 return fn(self, **kwargs)
#
# File c:\Users\alfon\anaconda3\envs\PySR\Lib\site-packages\pytorch_lightning\trainer\trainer.py:404, in Trainer.__init__(self, accelerator, strategy, devices, num_nodes, precision, logger, callbacks, fast_dev_run, max_epochs, min_epochs, max_steps, min_steps, max_time, limit_train_batches, limit_val_batches, limit_test_batches, limit_predict_batches, overfit_batches, val_check_interval, check_val_every_n_epoch, num_sanity_val_steps, log_every_n_steps, enable_checkpointing, enable_progress_bar, enable_model_summary, accumulate_grad_batches, gradient_clip_val, gradient_clip_algorithm, deterministic, benchmark, inference_mode, use_distributed_sampler, profiler, detect_anomaly, barebones, plugins, sync_batchnorm, reload_dataloaders_every_n_epochs, default_root_dir, model_registry)
#     401 # init connectors
#     402 self._data_connector = _DataConnector(self)
# --> 404 self._accelerator_connector = _AcceleratorConnector(
#     405     devices=devices,
#     406     accelerator=accelerator,
#     407     strategy=strategy,
#     408     num_nodes=num_nodes,
#     409     sync_batchnorm=sync_batchnorm,
#     410     benchmark=benchmark,
#     411     use_distributed_sampler=use_distributed_sampler,
#     412     deterministic=deterministic,
#     413     precision=precision,
#     414     plugins=plugins,
#     415 )
#     416 self._logger_connector = _LoggerConnector(self)
#     417 self._callback_connector = _CallbackConnector(self)
#
# File c:\Users\alfon\anaconda3\envs\PySR\Lib\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:144, in _AcceleratorConnector.__init__(self, devices, num_nodes, accelerator, strategy, plugins, precision, sync_batchnorm, benchmark, use_distributed_sampler, deterministic)
#     142     self._accelerator_flag = self._choose_auto_accelerator()
#     143 elif self._accelerator_flag == "gpu":
# --> 144     self._accelerator_flag = self._choose_gpu_accelerator_backend()
#     146 self._check_device_config_and_set_final_flags(devices=devices, num_nodes=num_nodes)
#     147 self._set_parallel_devices_and_init_accelerator()
#
# File c:\Users\alfon\anaconda3\envs\PySR\Lib\site-packages\pytorch_lightning\trainer\connectors\accelerator_connector.py:354, in _AcceleratorConnector._choose_gpu_accelerator_backend()
#     352 if CUDAAccelerator.is_available():
#     353     return "cuda"
# --> 354 raise MisconfigurationException("No supported gpu backend found!")
#
# MisconfigurationException: No supported gpu backend found!

# %% [markdown]
# Here, we fit the neural network:

# %%
trainer.fit(model, train_dataloaders=train, val_dataloaders=test)

# %% [markdown]
# ## Latent vectors of network
#
# Let's get the input and output of the learned `g` function from the network over some random data:

# %%
np.random.seed(0)
idx = np.random.randint(0, 10000, size=1000)

X_for_pysr = Xt[idx]
y_i_for_pysr = model.g(X_for_pysr)[:, :, 0]
y_for_pysr = torch.sum(y_i_for_pysr, dim=1) / y_i_for_pysr.shape[1]
z_for_pysr = zt[idx]  # Use true values.

X_for_pysr.shape, y_i_for_pysr.shape

# %% [markdown]
# ## Learning over the network:
#
# Now, let's fit `g` using PySR.
#
# > **Warning**
# >
# > First, let's save the data, because sometimes PyTorch and juliacall's C bindings interfere and cause the colab kernel to crash. If we need to restart, we can just load the data without having to retrain the network:

# %%
nnet_recordings = {
    "g_input": X_for_pysr.detach().cpu().numpy().reshape(-1, 5),
    "g_output": y_i_for_pysr.detach().cpu().numpy().reshape(-1),
    "f_input": y_for_pysr.detach().cpu().numpy().reshape(-1, 1),
    "f_output": z_for_pysr.detach().cpu().numpy().reshape(-1),
}

# Save the data for later use:
import pickle as pkl

with open("nnet_recordings.pkl", "wb") as f:
    pkl.dump(nnet_recordings, f)

# %% [markdown]
# We can now load the data, including after a crash (be sure to re-run the import cells at the top of this notebook, including the one that starts juliacall).

# %%
import pickle as pkl

nnet_recordings = pkl.load(open("nnet_recordings.pkl", "rb"))
f_input = nnet_recordings["f_input"]
f_output = nnet_recordings["f_output"]
g_input = nnet_recordings["g_input"]
g_output = nnet_recordings["g_output"]

# %% [markdown]
# And now fit using a subsample of the data (symbolic regression only needs a small sample to find the best equation):

# %%
rstate = np.random.RandomState(0)
f_sample_idx = rstate.choice(f_input.shape[0], size=500, replace=False)

model = PySRRegressor(
    niterations=50,
    binary_operators=["+", "-", "*"],
    unary_operators=["cos", "square"],
)
model.fit(g_input[f_sample_idx], g_output[f_sample_idx])

# %% [markdown]
# If this segfaults, restart the notebook, and run the initial imports and juliacall part, but skip the PyTorch training. This is because PyTorch's C binding tends to interefere with juliacall. You can then re-run the `pkl.load` cell to import the data.

# %% [markdown]
# ## Validation

# %% [markdown]
# Recall we are searching for $f$ and $g$ such that:
# $$z=f(\sum g(x_i))$$
# which approximates the true relation:
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2 x_{i2})$$
#
# Let's see how well we did in recovering $g$:

# %%
model.equations_[["complexity", "loss", "equation"]]

# %% [markdown]
# A neural network can easily undo a linear transform (which commutes with the summation), so any affine transform in $g$ is to be expected. The network for $f$ has learned to undo the linear transform.
#
# This likely won't find the exact result, but it should find something similar. You may wish to try again but with many more `total_steps` for the neural network (10,000 is quite small!).
#
# Then, we can learn another analytic equation for $f$.

# %% [markdown]
# **Now, we can compose these together to get the time series model!**
#
# Think about what we just did: we found an analytical equation for $z$ in terms of $500$ datapoints, under the assumption that $z$ is a function of a sum of another function over an axis:
#
# $$ z = f(\sum_i g(x_i)) $$
#
# And we pulled out analytical copies for $g$ using symbolic regression.

# %% [markdown]
# # Other PySR Options

# %% [markdown]
# The full list of PySR parameters can be found here: https://ai.damtp.cam.ac.uk/pysr/api
